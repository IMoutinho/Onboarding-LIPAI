# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *observação (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
data = pd.read_csv('./dataset/GasPricesinBrazil_2004-2019.csv')

# %%
data
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# 106822  106822;2019-06-23;2019-06-29;NORDESTE;SERGIPE;...
#
# [106823 rows x 1 columns]

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
#carregando o dataset corretamente ==> nesse caso, usa o separador ';'
data = pd.read_csv('./dataset/GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
#exibe as 10 primeiras linhas do dataframe
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
# 6                 0.353                    0.150                       1.1
# 7                 0.515                    0.097                     1.116
# 8                 0.353                    0.101                     0.931
# 9                 0.277                    0.115                     0.947
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
# 6                      0.068                    0.7332
# 7                      0.091                    0.9923
# 8                      0.072                    0.7577
# 9                      0.091                    0.5643
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
# 6                     1.294                         0.062   5  2004
# 7                   1.36183                         0.082   5  2004
# 8                    1.2972                         0.077   5  2004
# 9                    1.3541                         0.096   5  2004
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  str
#  2   DATA FINAL                     106823 non-null  str
#  3   REGIÃO                         106823 non-null  str
#  4   ESTADO                         106823 non-null  str
#  5   PRODUTO                        106823 non-null  str
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  str
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  str
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  str
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  str
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  str
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  str
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  str
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), str(12)
# memory usage: 17.1 MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(data)
# Out:
# pandas.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
# Out:
# (106823, 21)

# %%
print (f'O DataFrame possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/atributos/variáveis')
# Out:
# O DataFrame possui 106823 linhas/observações/registros e 21 colunas/atributos/variáveis

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70.5, 15.2, 60.1],
    'eh jedi': [True, True, False]

})

# %%
personagens_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      str
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      float64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), str(1)
# memory usage: 207.0 bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O método `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='str')

# %%
type(personagens_df.columns)
# Out:
# pandas.Index

# %%
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %%
personagens_df_renomeado = personagens_df.rename(columns={
    'nome': 'Nome Completo',
    'idade': 'Idade',
    'peso': 'Peso',
    'eh jedi': 'Eh Jedi'

})

# %%
personagens_df_renomeado
# Out:
#     Nome Completo  Idade  Peso  Eh Jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
personagens_df.rename(columns={
    'nome': 'Nome Completo',
    'idade': 'Idade',
    'peso': 'Peso',
    'eh jedi': 'Eh Jedi'
}, inplace=True)

# %%
personagens_df
# Out:
#     Nome Completo  Idade  Peso  Eh Jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as colunas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
personagens_df.columns
# Out:
# Index(['Nome Completo', 'Idade', 'Peso', 'Eh Jedi'], dtype='str')

# %%
personagens_df.columns = ['NOME', 'IDADE', 'PESO', 'EH JEDI?']

# %%
personagens_df
# Out:
#              NOME  IDADE  PESO  EH JEDI?
# 0  Luke Skywalker     16  70.5      True
# 1            Yoda   1000  15.2      True
# 2       Palpatine     70  60.1     False

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
#selecionando uma coluna inteira
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: str

# %%
#selecionando uma coluna inteira. Esta forma de acesso só funciona para colunas com nomes sem espaços, acentos e etc (caracteres invalidos)
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: str

# %%
type(data['ESTADO'])
# Out:
# pandas.Series

# %%
#selecionando a observação indexada no índice [1] do DataFrame
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %%
type(data.iloc[1])
# Out:
# pandas.Series

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.5, 6.0, 9.5])
# Out:
# 0    5.5
# 1    6.0
# 2    9.5
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([5.5, 6.0, 9.5], index=['Prova 1', 'Prova 2', 'Projeto'], name='Notas do Luke Skywalker')
# Out:
# Prova 1    5.5
# Prova 2    6.0
# Projeto    9.5
# Name: Notas do Luke Skywalker, dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
produto_view = data['PRODUTO'] # A series retornada referente à coluna não é uma cópia, mas sim uma referência/view da coluna do dataframe original. Portanto, alterações feitas nessa série serão refletidas no dataframe original.
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %%
produto_copy_bkp = data['PRODUTO'].copy() # Criando uma cópia da coluna 'PRODUTO' do DataFrame original. Modificações feitas nessa cópia não afetarão o DataFrame original.
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %%
data['PRODUTO'] = 'Combustível' #atribuindo o valor constante 'Combustível' à cada linha do dataframe na coluna 'PRODUTO'

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
# 3  Combustível                           162              R$/l
# 4  Combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novos_produtos = [f'Produto {i}'for i in range(nrows)]
len(novos_produtos)
# Out:
# 106823

# %%
# a quantidade de elementos da lista 'novos_produtos' é igual ao número de linhas do dataframe
data['PRODUTO'] = novos_produtos

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO         PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       Produto 0                           127
# 1                     GOIAS       Produto 1                           387
# 2               MATO GROSSO       Produto 2                           192
# 3        MATO GROSSO DO SUL       Produto 3                           162
# 4                   ALAGOAS       Produto 4                           103
# ...                     ...             ...                           ...
# 106818  RIO GRANDE DO NORTE  Produto 106818                             7
# 106819    RIO GRANDE DO SUL  Produto 106819                            23
# 106820       SANTA CATARINA  Produto 106820                            24
# 106821            SAO PAULO  Produto 106821                            52
# 106822              SERGIPE  Produto 106822                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
print(produto_view)
print(produto_copy_bkp)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: str

# %%
#voltando para os produtos originais
data['PRODUTO'] = produto_copy_bkp
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
#criando uma coluna a partir de um valor constante/default
#após isso todas as linhas do dataframe terão o valor 'DEFAULT' na coluna 'Coluna Sem Noção'
data['COLUNA SEM NOÇÃO'] = 'DEFAULT'
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                1.288                  0.016  ...                 0.463
# 1                1.162                  0.114  ...                 0.399
# 2                1.389                  0.097  ...                 0.419
# 3                1.262                  0.070  ...                 0.432
# 4                1.181                  0.078  ...                  0.24
#
#    COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                     0.012                    0.825
# 1                     0.098                    0.763
# 2                     0.070                     0.97
# 3                     0.055                     0.83
# 4                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    COLUNA SEM NOÇÃO
# 0           DEFAULT
# 1           DEFAULT
# 2           DEFAULT
# 3           DEFAULT
# 4           DEFAULT
#
# [5 rows x 22 columns]

# %%
data['COLUNA A PARTIR DE LISTA'] = range(data.shape[0])
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                      0.97
# 3                          0.055                      0.83
# 4                          0.066                     0.941
# ...                          ...                       ...
# 106818                     0.018                     2.756
# 106819                     0.038                     2.451
# 106820                     0.065                     1.998
# 106821                     0.076                     2.374
# 106822                     0.001                     2.518
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.11                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 106818                          0                      2.756
# 106819                      0.402                     1.9842
# 106820                          0                     1.9981
# 106821                      0.165                     2.0179
# 106822                          0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                         0.133   5  2004
# 1                           1.05                         0.115   5  2004
# 2                          1.161                         0.098   5  2004
# 3                        1.22242                         0.143   5  2004
# 4                         1.0317                         0.082   5  2004
# ...                          ...                           ...  ..   ...
# 106818                     2.756                             0   6  2019
# 106819                    2.8661                         0.164   6  2019
# 106820                    1.9981                             0   6  2019
# 106821                    2.5093                          0.07   6  2019
# 106822                    2.5175                             0   6  2019
#
#        COLUNA SEM NOÇÃO  COLUNA A PARTIR DE LISTA
# 0               DEFAULT                         0
# 1               DEFAULT                         1
# 2               DEFAULT                         2
# 3               DEFAULT                         3
# 4               DEFAULT                         4
# ...                 ...                       ...
# 106818          DEFAULT                    106818
# 106819          DEFAULT                    106819
# 106820          DEFAULT                    106820
# 106821          DEFAULT                    106821
# 106822          DEFAULT                    106822
#
# [106823 rows x 23 columns]

# %%
#data['não funciona'] = [1,2,3]
#não funciona pq a quantidade de elemtnos da lista a serem atribuidos na coluna são diferentes da quantidade de linhas do dataframe

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA SEM NOÇÃO  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    COLUNA A PARTIR DE LISTA
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
#
# [5 rows x 23 columns]

# %%
data['PREÇO MÉDIO REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA']* 5.18
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   COLUNA SEM NOÇÃO COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                        6.67184
# 1          DEFAULT                        1                        6.01916
# 2          DEFAULT                        2                        7.19502
# 3          DEFAULT                        3                        6.53716
# 4          DEFAULT                        4                        6.11758
#
# [5 rows x 24 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA SEM NOÇÃO  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#        COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 0                             0                        6.67184
# 1                             1                        6.01916
# 2                             2                        7.19502
# 3                             3                        6.53716
# 4                             4                        6.11758
# ...                         ...                            ...
# 106818                   106818                       18.51332
# 106819                   106819                       17.61718
# 106820                   106820                       15.08416
# 106821                   106821                       15.64360
# 106822                   106822                       19.15046
#
# [106823 rows x 24 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='str')

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras (Indexação)

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma amostra/linha:**

# %%
#selecionando a linha 1 que é a observação de indice 1 do dataframe
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# COLUNA SEM NOÇÃO                          DEFAULT
# COLUNA A PARTIR DE LISTA                        1
# PREÇO MÉDIO REVENDA (dólares)             6.01916
# Name: 1, dtype: object

# %% [markdown]
# **Selecionando múltiplas observações/linhas:**

# %%
#selecionando as linhas de índice de 0 a 5(incluso)
data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
# 5                1.383                  0.132  ...                     0.957
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
#
#   COLUNA SEM NOÇÃO COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                        6.67184
# 1          DEFAULT                        1                        6.01916
# 2          DEFAULT                        2                        7.19502
# 3          DEFAULT                        3                        6.53716
# 4          DEFAULT                        4                        6.11758
# 5          DEFAULT                        5                        7.16394
#
# [6 rows x 24 columns]

# %% [markdown]
# **Selecionando múltiplias amostras/linhas:**

# %%
#selecionando as linhas de indice de 10 a 15, sendo 15 incluso
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 10                1.573                  0.134  ...                     1.079
# 11                1.276                  0.116  ...                     0.944
# 12                1.301                  0.109  ...                      0.98
# 13                1.805                  0.134  ...                     1.116
# 14                1.785                  0.035  ...                     1.373
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 10                       0.078                    0.8857
# 11                       0.078                    0.7119
# 12                       0.052                    0.8267
# 13                       0.171                     0.767
# 14                       0.167                    0.8339
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 10                     1.2499                         0.072   5  2004
# 11                     1.1386                         0.083   5  2004
# 12                     1.1059                         0.053   5  2004
# 13                     1.2992                         0.153   5  2004
# 14                     1.4912                         0.122   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    COLUNA SEM NOÇÃO COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 10          DEFAULT                       10                        8.14814
# 11          DEFAULT                       11                        6.60968
# 12          DEFAULT                       12                        6.73918
# 13          DEFAULT                       13                        9.34990
# 14          DEFAULT                       14                        9.24630
# 15          DEFAULT                       15                        8.17404
#
# [6 rows x 24 columns]

# %%
#selecionando as linhas de observa~oes de indice 1, 5 , 10 e 15
data.iloc[[1,5,10,15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# 10                1.573                  0.134  ...                     1.079
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                    0.5013
# 5                        0.128                    0.5686
# 10                       0.078                    0.8857
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1                        1.05                         0.115   5  2004
# 5                        1.35                         0.134   5  2004
# 10                     1.2499                         0.072   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    COLUNA SEM NOÇÃO COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 1           DEFAULT                        1                        6.01916
# 5           DEFAULT                        5                        7.16394
# 10          DEFAULT                       10                        8.14814
# 15          DEFAULT                       15                        8.17404
#
# [4 rows x 24 columns]

# %%
#selecionando as linhas/observações de indices 5, 1, 15, 10
data.iloc[[5,15, 1, 10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 15                1.578                  0.123  ...                     1.137
# 1                 1.162                  0.114  ...                     0.763
# 10                1.573                  0.134  ...                     1.079
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                        0.128                    0.5686
# 15                       0.068                    0.9515
# 1                        0.088                    0.5013
# 10                       0.078                    0.8857
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5                        1.35                         0.134   5  2004
# 15                     1.2109                          0.06   5  2004
# 1                        1.05                         0.115   5  2004
# 10                     1.2499                         0.072   5  2004
#
#    COLUNA SEM NOÇÃO COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 5           DEFAULT                        5                        7.16394
# 15          DEFAULT                       15                        8.17404
# 1           DEFAULT                        1                        6.01916
# 10          DEFAULT                       10                        8.14814
#
# [4 rows x 24 columns]

# %%
#retornar o valor da linha de inidice 1, coluna 4 ('ESTADO')
data.iloc[1,4]
# Out:
# 'GOIAS'

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
#retorna a linha de índica 0 (implicito) ==> usando o iloc
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
#retorna o valor da linha de inidice 0 (implicito) e coluna de indice 0 (implicito) ==> usando o iloc
pesquisa_de_satisfacao.iloc[0,1]
# Out:
# np.int64(131)

# %%
#retorna a linha cujo o rótulo do índice é 'XboxOne' ==> usando o loc
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
#NÃO FUNCIONA ===> iloc tentando acessar indice com rótulo
#pesquisa_de_satisfacao.iloc['XboxOne']

# %%
#NÃO FUNCIONA ===> loc tentando acessar indice com posição
#pesquisa_de_satisfacao.loc[0]

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
#retorna o valor da linha 'Playstation4' e coluna 'ruim'
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# np.int64(2)

# %%
#selecionando as linhas de indice rotulado 'XboxOne' e 'Switch'
pesquisa_de_satisfacao.loc[['XboxOne','Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
#retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
#retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %% [markdown]
# ### OBSERVAÇÃO
# **Índices Númericos**, por default, possuem **rótulos que correspondem aos seus valores númericos.**

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   COLUNA SEM NOÇÃO COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                        6.67184
# 1          DEFAULT                        1                        6.01916
# 2          DEFAULT                        2                        7.19502
# 3          DEFAULT                        3                        6.53716
# 4          DEFAULT                        4                        6.11758
#
# [5 rows x 24 columns]

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# COLUNA SEM NOÇÃO                          DEFAULT
# COLUNA A PARTIR DE LISTA                        1
# PREÇO MÉDIO REVENDA (dólares)             6.01916
# Name: 1, dtype: object

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   COLUNA SEM NOÇÃO COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                        6.67184
# 1          DEFAULT                        1                        6.01916
# 2          DEFAULT                        2                        7.19502
# 3          DEFAULT                        3                        6.53716
# 4          DEFAULT                        4                        6.11758
#
# [5 rows x 24 columns]

# %%
#retornando a coluna/atributo 'ESTADO'
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: str

# %%
#retornando a coluna/atributo 'ESTADO'
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: str

# %%
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: str

# %%
#a forma de acesso de colunas por .NOME_DA_COLUNA só funciona para colunas com nomes sem espaços, acentos e etc (caracteres invalidos)
#NÃO FUNCIONA
#data.DATA INICIAL

# %%
#para colunas cujos rótulso possuem caracteres inválidos, espaços, acentos, etc, a forma de acesso é usando colchetes e aspas, via string
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: str

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %%
#selecionando multiplas colunas: 'PRODUTO', 'ESTADO' e 'REGIÃO'
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   COLUNA SEM NOÇÃO COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                        6.67184
# 1          DEFAULT                        1                        6.01916
# 2          DEFAULT                        2                        7.19502
# 3          DEFAULT                        3                        6.53716
# 4          DEFAULT                        4                        6.11758
#
# [5 rows x 24 columns]

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
#deleta/remove in-place, ou seja, no proprio dataframe, a coluna de rotulo: Unamed: 0
del data['Unnamed: 0']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO COLUNA SEM NOÇÃO  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    COLUNA A PARTIR DE LISTA  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                        6.67184
# 1                         1                        6.01916
# 2                         2                        7.19502
# 3                         3                        6.53716
# 4                         4                        6.11758
#
# [5 rows x 23 columns]

# %% [markdown]
# Vamos agora remover as colunas fictícias criadas nos vídeos para estudo.

# %%
del data['COLUNA SEM NOÇÃO']
del data['COLUNA A PARTIR DE LISTA']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('./dataset/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data = pd.read_csv('./dataset/GasPricesinBrazil_2004-2019_preprocessado.csv')

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %%
#mostra todos os estados cujos os preço dos combustiveis foram registrados no dataset
#mais tecnicamente, mostra os valores únicos da coluna 'ESTADO' do DataFrame
data.ESTADO.unique()
# Out:
# <StringArray>
# [   'DISTRITO FEDERAL',               'GOIAS',         'MATO GROSSO',
#   'MATO GROSSO DO SUL',             'ALAGOAS',               'BAHIA',
#                'CEARA',            'MARANHAO',             'PARAIBA',
#           'PERNAMBUCO',               'PIAUI', 'RIO GRANDE DO NORTE',
#              'SERGIPE',                'ACRE',               'AMAPA',
#             'AMAZONAS',                'PARA',            'RONDONIA',
#              'RORAIMA',           'TOCANTINS',      'ESPIRITO SANTO',
#         'MINAS GERAIS',      'RIO DE JANEIRO',           'SAO PAULO',
#               'PARANA',   'RIO GRANDE DO SUL',      'SANTA CATARINA']
# Length: 27, dtype: str

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (observações) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
#Faz uma comparação elemento a elemento da series da coluna 'ESTADO' retornando uma series de booleans
data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
#salvando essa series de booleans em uma variável chamada 'selecao'
selecao = data['ESTADO'] == 'SAO PAULO'

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.Series

# %%
data.shape
# Out:
# (106823, 21)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                    0.111
# 50                      0.19                    0.108
# 77                     0.209                    0.086
# 104                    0.216                    0.085
# 131                    0.205                    0.079
# ...                      ...                      ...
# 106724                 0.401                    0.045
# 106751                 0.451                    0.047
# 106778                 0.429                    0.044
# 106805                17.679                    0.091
# 106821                 0.646                    0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 23                             0.098   5  2004                        3.97824
# 50                             0.087   5  2004                        3.96788
# 77                             0.103   5  2004                        4.26314
# 104                            0.112   5  2004                        4.59466
# 131                            0.104   6  2004                        4.63092
# ...                              ...  ..   ...                            ...
# 106724                         0.032   6  2019                       17.86064
# 106751                         0.036   6  2019                       18.51332
# 106778                         0.026   6  2019                       21.45556
# 106805                         0.103   6  2019                      346.50574
# 106821                          0.07   6  2019                       15.64360
#
# [4263 rows x 21 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                    0.111
# 50                      0.19                    0.108
# 77                     0.209                    0.086
# 104                    0.216                    0.085
# 131                    0.205                    0.079
# ...                      ...                      ...
# 106724                 0.401                    0.045
# 106751                 0.451                    0.047
# 106778                 0.429                    0.044
# 106805                17.679                    0.091
# 106821                 0.646                    0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 23                             0.098   5  2004                        3.97824
# 50                             0.087   5  2004                        3.96788
# 77                             0.103   5  2004                        4.26314
# 104                            0.112   5  2004                        4.59466
# 131                            0.104   6  2004                        4.63092
# ...                              ...  ..   ...                            ...
# 106724                         0.032   6  2019                       17.86064
# 106751                         0.036   6  2019                       18.51332
# 106778                         0.026   6  2019                       21.45556
# 106805                         0.103   6  2019                      346.50574
# 106821                          0.07   6  2019                       15.64360
#
# [4263 rows x 21 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %%
data.query('ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                    0.111
# 50                      0.19                    0.108
# 77                     0.209                    0.086
# 104                    0.216                    0.085
# 131                    0.205                    0.079
# ...                      ...                      ...
# 106724                 0.401                    0.045
# 106751                 0.451                    0.047
# 106778                 0.429                    0.044
# 106805                17.679                    0.091
# 106821                 0.646                    0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 23                             0.098   5  2004                        3.97824
# 50                             0.087   5  2004                        3.96788
# 77                             0.103   5  2004                        4.26314
# 104                            0.112   5  2004                        4.59466
# 131                            0.104   6  2004                        4.63092
# ...                              ...  ..   ...                            ...
# 106724                         0.032   6  2019                       17.86064
# 106751                         0.036   6  2019                       18.51332
# 106778                         0.026   6  2019                       21.45556
# 106805                         0.103   6  2019                      346.50574
# 106821                          0.07   6  2019                       15.64360
#
# [4263 rows x 21 columns]

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feita para os postos de São Paulo.

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"')
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                    0.111
# 50                      0.19                    0.108
# 77                     0.209                    0.086
# 104                    0.216                    0.085
# 131                    0.205                    0.079
# ...                      ...                      ...
# 106724                 0.401                    0.045
# 106751                 0.451                    0.047
# 106778                 0.429                    0.044
# 106805                17.679                    0.091
# 106821                 0.646                    0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 23                             0.098   5  2004                        3.97824
# 50                             0.087   5  2004                        3.96788
# 77                             0.103   5  2004                        4.26314
# 104                            0.112   5  2004                        4.59466
# 131                            0.104   6  2004                        4.63092
# ...                              ...  ..   ...                            ...
# 106724                         0.032   6  2019                       17.86064
# 106751                         0.036   6  2019                       18.51332
# 106778                         0.026   6  2019                       21.45556
# 106805                         0.103   6  2019                      346.50574
# 106821                          0.07   6  2019                       15.64360
#
# [4263 rows x 21 columns]

# %%
type(postos_sp)
# Out:
# pandas.DataFrame

# %%
postos_sp.shape
# Out:
# (4263, 21)

# %%
postos_sp.head()
# Out:
#     DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23    2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50    2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77    2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                           4047              R$/l                0.768
# 50                           4066              R$/l                0.766
# 77                           4077              R$/l                0.823
# 104                          4073              R$/l                0.887
# 131                          4082              R$/l                0.894
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 23                   0.085                 0.590  ...                 0.198
# 50                   0.083                 0.590  ...                  0.19
# 77                   0.071                 0.620  ...                 0.209
# 104                  0.075                 0.639  ...                 0.216
# 131                  0.071                 0.669  ...                 0.205
#
#     COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 23                     0.111                      0.57
# 50                     0.108                     0.576
# 77                     0.086                     0.614
# 104                    0.085                     0.671
# 131                    0.079                     0.689
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                       0.056                    0.4271
# 50                        0.05                   0.43204
# 77                       0.063                   0.34951
# 104                      0.075                    0.3398
# 131                      0.072                   0.47797
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 23                     1.4123                         0.098   5  2004
# 50                     0.9724                         0.087   5  2004
# 77                      1.412                         0.103   5  2004
# 104                    1.0669                         0.112   5  2004
# 131                    1.0669                         0.104   6  2004
#
#      PREÇO MÉDIO REVENDA (dólares)
# 23                         3.97824
# 50                         3.96788
# 77                         4.26314
# 104                        4.59466
# 131                        4.63092
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Resetando os índices
#
# Note que os índices das linhas/registros após a filtragem **continuam sendo os mesmos** do DataFrame original.
# Em muitas situações, manter essa informação será importante.
#
# Mas se você quiser **resetar os índices** do data frame filtrado, fazendo com que os registros comecem com índice 0 até num_linhas-1, use o método .reset_index.

# %%
postos_sp.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                     0.085                 0.590  ...                 0.198
# 1                     0.083                 0.590  ...                  0.19
# 2                     0.071                 0.620  ...                 0.209
# 3                     0.075                 0.639  ...                 0.216
# 4                     0.071                 0.669  ...                 0.205
# ...                     ...                   ...  ...                   ...
# 4258                  0.156                 3.099  ...                 0.401
# 4259                  0.169                 3.199  ...                 0.451
# 4260                  0.183                 3.769  ...                 0.429
# 4261                  6.100                50.000  ...                17.679
# 4262                  0.229                 2.699  ...                 0.646
#
#      COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                       0.111                      0.57
# 1                       0.108                     0.576
# 2                       0.086                     0.614
# 3                       0.085                     0.671
# 4                       0.079                     0.689
# ...                       ...                       ...
# 4258                    0.045                     3.047
# 4259                    0.047                     3.123
# 4260                    0.044                     3.713
# 4261                    0.091                    49.214
# 4262                    0.076                     2.374
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                    0.4271
# 1                          0.05                   0.43204
# 2                         0.063                   0.34951
# 3                         0.075                    0.3398
# 4                         0.072                   0.47797
# ...                         ...                       ...
# 4258                      0.097                    2.8599
# 4259                      0.111                     2.885
# 4260                      0.097                      3.52
# 4261                      5.071                     40.19
# 4262                      0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
#       PREÇO MÉDIO REVENDA (dólares)
# 0                           3.97824
# 1                           3.96788
# 2                           4.26314
# 3                           4.59466
# 4                           4.63092
# ...                             ...
# 4258                       17.86064
# 4259                       18.51332
# 4260                       21.45556
# 4261                      346.50574
# 4262                       15.64360
#
# [4263 rows x 21 columns]

# %%
#ainda não foi alterado, precisamos usar o atributo ou parametro inplace=True para alterar o dataframe original
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                    0.111
# 50                      0.19                    0.108
# 77                     0.209                    0.086
# 104                    0.216                    0.085
# 131                    0.205                    0.079
# ...                      ...                      ...
# 106724                 0.401                    0.045
# 106751                 0.451                    0.047
# 106778                 0.429                    0.044
# 106805                17.679                    0.091
# 106821                 0.646                    0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 23                             0.098   5  2004                        3.97824
# 50                             0.087   5  2004                        3.96788
# 77                             0.103   5  2004                        4.26314
# 104                            0.112   5  2004                        4.59466
# 131                            0.104   6  2004                        4.63092
# ...                              ...  ..   ...                            ...
# 106724                         0.032   6  2019                       17.86064
# 106751                         0.036   6  2019                       18.51332
# 106778                         0.026   6  2019                       21.45556
# 106805                         0.103   6  2019                      346.50574
# 106821                          0.07   6  2019                       15.64360
#
# [4263 rows x 21 columns]

# %%
postos_sp.reset_index(drop=True, inplace=True)
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                     0.085                 0.590  ...                 0.198
# 1                     0.083                 0.590  ...                  0.19
# 2                     0.071                 0.620  ...                 0.209
# 3                     0.075                 0.639  ...                 0.216
# 4                     0.071                 0.669  ...                 0.205
# ...                     ...                   ...  ...                   ...
# 4258                  0.156                 3.099  ...                 0.401
# 4259                  0.169                 3.199  ...                 0.451
# 4260                  0.183                 3.769  ...                 0.429
# 4261                  6.100                50.000  ...                17.679
# 4262                  0.229                 2.699  ...                 0.646
#
#      COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                       0.111                      0.57
# 1                       0.108                     0.576
# 2                       0.086                     0.614
# 3                       0.085                     0.671
# 4                       0.079                     0.689
# ...                       ...                       ...
# 4258                    0.045                     3.047
# 4259                    0.047                     3.123
# 4260                    0.044                     3.713
# 4261                    0.091                    49.214
# 4262                    0.076                     2.374
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                    0.4271
# 1                          0.05                   0.43204
# 2                         0.063                   0.34951
# 3                         0.075                    0.3398
# 4                         0.072                   0.47797
# ...                         ...                       ...
# 4258                      0.097                    2.8599
# 4259                      0.111                     2.885
# 4260                      0.097                      3.52
# 4261                      5.071                     40.19
# 4262                      0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
#       PREÇO MÉDIO REVENDA (dólares)
# 0                           3.97824
# 1                           3.96788
# 2                           4.26314
# 3                           4.59466
# 4                           4.63092
# ...                             ...
# 4258                       17.86064
# 4259                       18.51332
# 4260                       21.45556
# 4261                      346.50574
# 4262                       15.64360
#
# [4263 rows x 21 columns]

# %%
#alternativa muito comum
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                     0.085                 0.590  ...                 0.198
# 1                     0.083                 0.590  ...                  0.19
# 2                     0.071                 0.620  ...                 0.209
# 3                     0.075                 0.639  ...                 0.216
# 4                     0.071                 0.669  ...                 0.205
# ...                     ...                   ...  ...                   ...
# 4258                  0.156                 3.099  ...                 0.401
# 4259                  0.169                 3.199  ...                 0.451
# 4260                  0.183                 3.769  ...                 0.429
# 4261                  6.100                50.000  ...                17.679
# 4262                  0.229                 2.699  ...                 0.646
#
#      COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                       0.111                      0.57
# 1                       0.108                     0.576
# 2                       0.086                     0.614
# 3                       0.085                     0.671
# 4                       0.079                     0.689
# ...                       ...                       ...
# 4258                    0.045                     3.047
# 4259                    0.047                     3.123
# 4260                    0.044                     3.713
# 4261                    0.091                    49.214
# 4262                    0.076                     2.374
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                    0.4271
# 1                          0.05                   0.43204
# 2                         0.063                   0.34951
# 3                         0.075                    0.3398
# 4                         0.072                   0.47797
# ...                         ...                       ...
# 4258                      0.097                    2.8599
# 4259                      0.111                     2.885
# 4260                      0.097                      3.52
# 4261                      5.071                     40.19
# 4262                      0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
#       PREÇO MÉDIO REVENDA (dólares)
# 0                           3.97824
# 1                           3.96788
# 2                           4.26314
# 3                           4.59466
# 4                           4.63092
# ...                             ...
# 4258                       17.86064
# 4259                       18.51332
# 4260                       21.45556
# 4261                      346.50574
# 4262                       15.64360
#
# [4263 rows x 21 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %%
data['ESTADO']=='RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
selecao = (data['ESTADO']=='RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 2501                    0.148                 1.589  ...
# 2528                    0.149                 1.779  ...
# 2555                    0.138                 1.799  ...
# 2582                    0.146                 1.760  ...
# 2609                    0.143                 1.789  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 2501                   0.222                    0.073
# 2528                   0.286                    0.070
# 2555                   0.268                    0.064
# 2582                   0.231                    0.067
# 2609                   0.209                    0.066
# ...                      ...                      ...
# 106718                 0.467                    0.047
# 106745                   0.5                    0.051
# 106772                 0.538                    0.033
# 106799                17.475                    0.089
# 106817                 0.707                    0.084
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                       1.806                       0.11
# 2528                       1.839                      0.117
# 2555                       1.895                      0.134
# 2582                       1.935                       0.14
# 2609                       1.963                      0.133
# ...                          ...                        ...
# 106718                     3.102                      0.119
# 106745                     3.197                      0.127
# 106772                      4.39                      0.097
# 106799                    47.535                      3.934
# 106817                     2.404                      0.174
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                        1.31                    2.1358
# 2528                       1.438                    2.2801
# 2555                        1.43                    2.3454
# 2582                       1.438                    2.2925
# 2609                       1.438                    2.2513
# ...                          ...                       ...
# 106718                     2.886                    3.5162
# 106745                    2.9772                    3.5388
# 106772                       4.2                     4.618
# 106799                        39                      58.2
# 106817                     2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 2501                           0.061   2  2006                       10.50504
# 2528                           0.064   3  2006                       11.00750
# 2555                           0.071   3  2006                       11.20434
# 2582                           0.072   3  2006                       11.21988
# 2609                           0.068   3  2006                       11.25096
# ...                              ...  ..   ...                            ...
# 106718                         0.038   6  2019                       18.48742
# 106745                          0.04   6  2019                       19.15046
# 106772                         0.022   6  2019                       25.52704
# 106799                         0.083   6  2019                      336.75180
# 106817                         0.072   6  2019                       16.11498
#
# [3054 rows x 21 columns]

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
#data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
data.query('ESTADO == "RIO DE JANEIRO" or ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 23                              4047              R$/l                0.768
# 49                               948              R$/l                1.092
# 50                              4066              R$/l                0.766
# 76                               973              R$/l                1.103
# ...                              ...               ...                  ...
# 106778                          1644              R$/l                4.142
# 106799                           221           R$/13Kg               65.010
# 106805                          1017           R$/13Kg               66.893
# 106817                           124             R$/m3                3.111
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 22                      0.154                 0.740  ...
# 23                      0.085                 0.590  ...
# 49                      0.157                 0.740  ...
# 50                      0.083                 0.590  ...
# 76                      0.140                 0.770  ...
# ...                       ...                   ...  ...
# 106778                  0.183                 3.769  ...
# 106799                  5.812                50.000  ...
# 106805                  6.100                50.000  ...
# 106817                  0.260                 2.799  ...
# 106821                  0.229                 2.699  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 22                     0.312                    0.140
# 23                     0.198                    0.111
# 49                     0.284                    0.144
# 50                      0.19                    0.108
# 76                     0.281                    0.127
# ...                      ...                      ...
# 106778                 0.429                    0.044
# 106799                17.475                    0.089
# 106805                17.679                    0.091
# 106817                 0.707                    0.084
# 106821                 0.646                    0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                      0.173
# 23                          0.57                      0.056
# 49                         0.808                      0.175
# 50                         0.576                       0.05
# 76                         0.822                      0.166
# ...                          ...                        ...
# 106778                     3.713                      0.097
# 106799                    47.535                      3.934
# 106805                    49.214                      5.071
# 106817                     2.404                      0.174
# 106821                     2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                         0.326                     1.263
# 23                        0.4271                    1.4123
# 49                        0.3257                    1.2921
# 50                       0.43204                    0.9724
# 76                       0.38909                    1.1859
# ...                          ...                       ...
# 106778                      3.52                    4.0892
# 106799                        39                      58.2
# 106805                     40.19                        72
# 106817                     2.126                    2.7909
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 22                              0.22   5  2004                        5.68764
# 23                             0.098   5  2004                        3.97824
# 49                             0.217   5  2004                        5.65656
# 50                             0.087   5  2004                        3.96788
# 76                             0.202   5  2004                        5.71354
# ...                              ...  ..   ...                            ...
# 106778                         0.026   6  2019                       21.45556
# 106799                         0.083   6  2019                      336.75180
# 106805                         0.103   6  2019                      346.50574
# 106817                         0.072   6  2019                       16.11498
# 106821                          0.07   6  2019                       15.64360
#
# [8526 rows x 21 columns]

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (observação a observação) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (observação a observação) do DataFrame, quais são os registros cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, se fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_rj=data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj =data[selecao_rj]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 49                               948              R$/l                1.092
# 76                               973              R$/l                1.103
# 103                              955              R$/l                1.149
# 130                              966              R$/l                1.165
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 22                      0.154                 0.740  ...
# 49                      0.157                 0.740  ...
# 76                      0.140                 0.770  ...
# 103                     0.156                 0.799  ...
# 130                     0.154                 0.830  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 22                     0.312                    0.140
# 49                     0.284                    0.144
# 76                     0.281                    0.127
# 103                      0.3                    0.136
# 130                    0.254                    0.132
# ...                      ...                      ...
# 106718                 0.467                    0.047
# 106745                   0.5                    0.051
# 106772                 0.538                    0.033
# 106799                17.475                    0.089
# 106817                 0.707                    0.084
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                      0.173
# 49                         0.808                      0.175
# 76                         0.822                      0.166
# 103                        0.849                      0.188
# 130                        0.911                      0.198
# ...                          ...                        ...
# 106718                     3.102                      0.119
# 106745                     3.197                      0.127
# 106772                      4.39                      0.097
# 106799                    47.535                      3.934
# 106817                     2.404                      0.174
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                         0.326                     1.263
# 49                        0.3257                    1.2921
# 76                       0.38909                    1.1859
# 103                       0.3453                    1.3667
# 130                          0.4                    1.3667
# ...                          ...                       ...
# 106718                     2.886                    3.5162
# 106745                    2.9772                    3.5388
# 106772                       4.2                     4.618
# 106799                        39                      58.2
# 106817                     2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 22                              0.22   5  2004                        5.68764
# 49                             0.217   5  2004                        5.65656
# 76                             0.202   5  2004                        5.71354
# 103                            0.221   5  2004                        5.95182
# 130                            0.217   6  2004                        6.03470
# ...                              ...  ..   ...                            ...
# 106718                         0.038   6  2019                       18.48742
# 106745                          0.04   6  2019                       19.15046
# 106772                         0.022   6  2019                       25.52704
# 106799                         0.083   6  2019                      336.75180
# 106817                         0.072   6  2019                       16.11498
#
# [4263 rows x 21 columns]

# %%
selecao_precomedio_rj = postos_rj['PREÇO MÉDIO REVENDA'] > 2.0
selecao_precomedio_rj
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postos_rj_precomaior_2 = postos_rj[selecao_precomedio_rj]
postos_rj_precomaior_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 2501                    0.148                 1.589  ...
# 2528                    0.149                 1.779  ...
# 2555                    0.138                 1.799  ...
# 2582                    0.146                 1.760  ...
# 2609                    0.143                 1.789  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 2501                   0.222                    0.073
# 2528                   0.286                    0.070
# 2555                   0.268                    0.064
# 2582                   0.231                    0.067
# 2609                   0.209                    0.066
# ...                      ...                      ...
# 106718                 0.467                    0.047
# 106745                   0.5                    0.051
# 106772                 0.538                    0.033
# 106799                17.475                    0.089
# 106817                 0.707                    0.084
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                       1.806                       0.11
# 2528                       1.839                      0.117
# 2555                       1.895                      0.134
# 2582                       1.935                       0.14
# 2609                       1.963                      0.133
# ...                          ...                        ...
# 106718                     3.102                      0.119
# 106745                     3.197                      0.127
# 106772                      4.39                      0.097
# 106799                    47.535                      3.934
# 106817                     2.404                      0.174
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                        1.31                    2.1358
# 2528                       1.438                    2.2801
# 2555                        1.43                    2.3454
# 2582                       1.438                    2.2925
# 2609                       1.438                    2.2513
# ...                          ...                       ...
# 106718                     2.886                    3.5162
# 106745                    2.9772                    3.5388
# 106772                       4.2                     4.618
# 106799                        39                      58.2
# 106817                     2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 2501                           0.061   2  2006                       10.50504
# 2528                           0.064   3  2006                       11.00750
# 2555                           0.071   3  2006                       11.20434
# 2582                           0.072   3  2006                       11.21988
# 2609                           0.068   3  2006                       11.25096
# ...                              ...  ..   ...                            ...
# 106718                         0.038   6  2019                       18.48742
# 106745                          0.04   6  2019                       19.15046
# 106772                         0.022   6  2019                       25.52704
# 106799                         0.083   6  2019                      336.75180
# 106817                         0.072   6  2019                       16.11498
#
# [3054 rows x 21 columns]

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %%
selecao1 = (data['ESTADO']== 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
selecao2 = (data['PRODUTO'] == 'GASOLINA COMUM')
selecao3 = (data['PREÇO MÉDIO REVENDA'] > 2.0)

selecao_final = selecao1 & selecao2 & selecao3
selecao_final
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
data_filtrada = data[selecao_final]
data_filtrada
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12113                   0.113                 1.700  ...
# 12140                   0.108                 1.700  ...
# 12167                   0.111                 1.730  ...
# 12194                   0.107                 1.760  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 12086                  0.254                    0.053
# 12113                  0.252                    0.055
# 12140                  0.252                    0.053
# 12167                  0.251                    0.054
# 12194                  0.247                    0.052
# ...                      ...                      ...
# 106479                 0.425                    0.042
# 106623                 0.544                    0.032
# 106629                 0.443                    0.042
# 106772                 0.538                    0.033
# 106778                 0.429                    0.044
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                      1.791                      0.047
# 12113                      1.788                      0.049
# 12140                       1.79                      0.046
# 12167                      1.802                      0.055
# 12194                      1.816                      0.054
# ...                          ...                        ...
# 106479                     3.785                      0.096
# 106623                     4.383                        0.1
# 106629                     3.725                      0.096
# 106772                      4.39                      0.097
# 106778                     3.713                      0.097
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12113                     1.5943                   1.99651
# 12140                    1.63596                    2.2137
# 12167                       1.64                   2.21425
# 12194                       1.64                   2.32425
# ...                          ...                       ...
# 106479                      3.52                    4.1007
# 106623                    4.1972                    4.6239
# 106629                     3.502                    4.0892
# 106772                       4.2                     4.618
# 106778                      3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 12086                          0.026   5  2004                       10.59310
# 12113                          0.027   5  2004                       10.56720
# 12140                          0.026   5  2004                       10.57756
# 12167                          0.031   5  2004                       10.63454
# 12194                           0.03   6  2004                       10.68634
# ...                              ...  ..   ...                            ...
# 106479                         0.025   6  2019                       21.80780
# 106623                         0.023   6  2019                       25.52186
# 106629                         0.026   6  2019                       21.59024
# 106772                         0.022   6  2019                       25.52704
# 106778                         0.026   6  2019                       21.45556
#
# [1564 rows x 21 columns]

# %%
print(data_filtrada['ESTADO'].unique())
print(data_filtrada['PRODUTO'].unique())
# Out:
# <StringArray>
# ['RIO DE JANEIRO', 'SAO PAULO']
# Length: 2, dtype: str
# <StringArray>
# ['GASOLINA COMUM']
# Length: 1, dtype: str

# %% [markdown]
# <br/>
#
# Alternativamente:

# %%
selecao1 = (data['ESTADO']== 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
postos_sp_rj = data[selecao1]


#apenas registros de SP e RJ
postos_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 23                              4047              R$/l                0.768
# 49                               948              R$/l                1.092
# 50                              4066              R$/l                0.766
# 76                               973              R$/l                1.103
# ...                              ...               ...                  ...
# 106778                          1644              R$/l                4.142
# 106799                           221           R$/13Kg               65.010
# 106805                          1017           R$/13Kg               66.893
# 106817                           124             R$/m3                3.111
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 22                      0.154                 0.740  ...
# 23                      0.085                 0.590  ...
# 49                      0.157                 0.740  ...
# 50                      0.083                 0.590  ...
# 76                      0.140                 0.770  ...
# ...                       ...                   ...  ...
# 106778                  0.183                 3.769  ...
# 106799                  5.812                50.000  ...
# 106805                  6.100                50.000  ...
# 106817                  0.260                 2.799  ...
# 106821                  0.229                 2.699  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 22                     0.312                    0.140
# 23                     0.198                    0.111
# 49                     0.284                    0.144
# 50                      0.19                    0.108
# 76                     0.281                    0.127
# ...                      ...                      ...
# 106778                 0.429                    0.044
# 106799                17.475                    0.089
# 106805                17.679                    0.091
# 106817                 0.707                    0.084
# 106821                 0.646                    0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                      0.173
# 23                          0.57                      0.056
# 49                         0.808                      0.175
# 50                         0.576                       0.05
# 76                         0.822                      0.166
# ...                          ...                        ...
# 106778                     3.713                      0.097
# 106799                    47.535                      3.934
# 106805                    49.214                      5.071
# 106817                     2.404                      0.174
# 106821                     2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                         0.326                     1.263
# 23                        0.4271                    1.4123
# 49                        0.3257                    1.2921
# 50                       0.43204                    0.9724
# 76                       0.38909                    1.1859
# ...                          ...                       ...
# 106778                      3.52                    4.0892
# 106799                        39                      58.2
# 106805                     40.19                        72
# 106817                     2.126                    2.7909
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 22                              0.22   5  2004                        5.68764
# 23                             0.098   5  2004                        3.97824
# 49                             0.217   5  2004                        5.65656
# 50                             0.087   5  2004                        3.96788
# 76                             0.202   5  2004                        5.71354
# ...                              ...  ..   ...                            ...
# 106778                         0.026   6  2019                       21.45556
# 106799                         0.083   6  2019                      336.75180
# 106805                         0.103   6  2019                      346.50574
# 106817                         0.072   6  2019                       16.11498
# 106821                          0.07   6  2019                       15.64360
#
# [8526 rows x 21 columns]

# %%
selecao2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
postos_sp_rj_gasolina_comum = postos_sp_rj[selecao2]

postos_sp_rj_gasolina_comum
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12087                           4107              R$/l                1.891
# 12113                           1055              R$/l                2.040
# 12114                           4133              R$/l                1.888
# 12140                           1091              R$/l                2.042
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12087                   0.101                 1.570  ...
# 12113                   0.113                 1.700  ...
# 12114                   0.101                 1.540  ...
# 12140                   0.108                 1.700  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 12086                  0.254                    0.053
# 12087                  0.235                    0.053
# 12113                  0.252                    0.055
# 12114                  0.233                    0.053
# 12140                  0.252                    0.053
# ...                      ...                      ...
# 106479                 0.425                    0.042
# 106623                 0.544                    0.032
# 106629                 0.443                    0.042
# 106772                 0.538                    0.033
# 106778                 0.429                    0.044
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                      1.791                      0.047
# 12087                      1.656                      0.064
# 12113                      1.788                      0.049
# 12114                      1.655                      0.063
# 12140                       1.79                      0.046
# ...                          ...                        ...
# 106479                     3.785                      0.096
# 106623                     4.383                        0.1
# 106629                     3.725                      0.096
# 106772                      4.39                      0.097
# 106778                     3.713                      0.097
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12087                       1.38                     1.944
# 12113                     1.5943                   1.99651
# 12114                       1.38                    1.9319
# 12140                    1.63596                    2.2137
# ...                          ...                       ...
# 106479                      3.52                    4.1007
# 106623                    4.1972                    4.6239
# 106629                     3.502                    4.0892
# 106772                       4.2                     4.618
# 106778                      3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 12086                          0.026   5  2004                       10.59310
# 12087                          0.039   5  2004                        9.79538
# 12113                          0.027   5  2004                       10.56720
# 12114                          0.038   5  2004                        9.77984
# 12140                          0.026   5  2004                       10.57756
# ...                              ...  ..   ...                            ...
# 106479                         0.025   6  2019                       21.80780
# 106623                         0.023   6  2019                       25.52186
# 106629                         0.026   6  2019                       21.59024
# 106772                         0.022   6  2019                       25.52704
# 106778                         0.026   6  2019                       21.45556
#
# [1570 rows x 21 columns]

# %%
selecao3 = (postos_sp_rj_gasolina_comum['PREÇO MÉDIO REVENDA'] > 2.0)
postos_sp_rj_gasolina_comum_precomaior_2 = postos_sp_rj_gasolina_comum[selecao3]

postos_sp_rj_gasolina_comum_precomaior_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12113                   0.113                 1.700  ...
# 12140                   0.108                 1.700  ...
# 12167                   0.111                 1.730  ...
# 12194                   0.107                 1.760  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 12086                  0.254                    0.053
# 12113                  0.252                    0.055
# 12140                  0.252                    0.053
# 12167                  0.251                    0.054
# 12194                  0.247                    0.052
# ...                      ...                      ...
# 106479                 0.425                    0.042
# 106623                 0.544                    0.032
# 106629                 0.443                    0.042
# 106772                 0.538                    0.033
# 106778                 0.429                    0.044
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                      1.791                      0.047
# 12113                      1.788                      0.049
# 12140                       1.79                      0.046
# 12167                      1.802                      0.055
# 12194                      1.816                      0.054
# ...                          ...                        ...
# 106479                     3.785                      0.096
# 106623                     4.383                        0.1
# 106629                     3.725                      0.096
# 106772                      4.39                      0.097
# 106778                     3.713                      0.097
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12113                     1.5943                   1.99651
# 12140                    1.63596                    2.2137
# 12167                       1.64                   2.21425
# 12194                       1.64                   2.32425
# ...                          ...                       ...
# 106479                      3.52                    4.1007
# 106623                    4.1972                    4.6239
# 106629                     3.502                    4.0892
# 106772                       4.2                     4.618
# 106778                      3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 12086                          0.026   5  2004                       10.59310
# 12113                          0.027   5  2004                       10.56720
# 12140                          0.026   5  2004                       10.57756
# 12167                          0.031   5  2004                       10.63454
# 12194                           0.03   6  2004                       10.68634
# ...                              ...  ..   ...                            ...
# 106479                         0.025   6  2019                       21.80780
# 106623                         0.023   6  2019                       25.52186
# 106629                         0.026   6  2019                       21.59024
# 106772                         0.022   6  2019                       25.52704
# 106778                         0.026   6  2019                       21.45556
#
# [1564 rows x 21 columns]

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao = (data['ANO']== 2008) | (data['ANO']== 2010) | (data['ANO'] == 2012)
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 5098                   0.29                    0.045
# 5099                  0.293                    0.062
# 5100                  0.278                    0.060
# 5101                  0.382                    0.025
# 5102                  0.199                    0.058
# ...                     ...                      ...
# 55754                 0.466                    0.008
# 55755                 0.566                    0.020
# 55756                     -                    0.017
# 55757                 0.397                    0.125
# 55758                 0.504                    0.018
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                      1.516                      0.061
# 5099                      1.323                       0.05
# 5100                      1.303                      0.073
# 5101                      1.449                      0.044
# 5102                        1.5                      0.062
# ...                         ...                        ...
# 55754                     1.425                      0.098
# 55755                     1.414                      0.028
# 55756                         -                          -
# 55757                     1.201                      0.182
# 55758                     1.343                      0.178
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                     1.3892                    1.6157
# 5099                     1.2242                    1.6173
# 5100                       1.14                      1.45
# 5101                     1.3247                    1.5514
# 5102                       1.39                    1.7689
# ...                         ...                       ...
# 55754                    1.2657                    1.4789
# 55755                    1.3997                    1.4608
# 55756                         -                         -
# 55757                    0.8354                     1.535
# 55758                    1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 5098                           0.04   1  2008                        9.35508
# 5099                          0.038   1  2008                        8.37088
# 5100                          0.056   1  2008                        8.18958
# 5101                           0.03   1  2008                        9.48458
# 5102                          0.041   1  2008                        8.80082
# ...                             ...  ..   ...                            ...
# 55754                         0.069  12  2012                        9.79538
# 55755                          0.02  12  2012                       10.25640
# 55756                             -  12  2012                       10.37554
# 55757                         0.152  12  2012                        8.27764
# 55758                         0.133  12  2012                        9.56746
#
# [19576 rows x 21 columns]

# %% [markdown]
# **ALTERNATIVA 2**

# %%
lista_de_anos = [2008, 2010, 2012]

# %%
selecao = data['ANO'].isin(lista_de_anos) #RETORNA UMA SERIES DE BOOLEANS
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 5098                   0.29                    0.045
# 5099                  0.293                    0.062
# 5100                  0.278                    0.060
# 5101                  0.382                    0.025
# 5102                  0.199                    0.058
# ...                     ...                      ...
# 55754                 0.466                    0.008
# 55755                 0.566                    0.020
# 55756                     -                    0.017
# 55757                 0.397                    0.125
# 55758                 0.504                    0.018
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                      1.516                      0.061
# 5099                      1.323                       0.05
# 5100                      1.303                      0.073
# 5101                      1.449                      0.044
# 5102                        1.5                      0.062
# ...                         ...                        ...
# 55754                     1.425                      0.098
# 55755                     1.414                      0.028
# 55756                         -                          -
# 55757                     1.201                      0.182
# 55758                     1.343                      0.178
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                     1.3892                    1.6157
# 5099                     1.2242                    1.6173
# 5100                       1.14                      1.45
# 5101                     1.3247                    1.5514
# 5102                       1.39                    1.7689
# ...                         ...                       ...
# 55754                    1.2657                    1.4789
# 55755                    1.3997                    1.4608
# 55756                         -                         -
# 55757                    0.8354                     1.535
# 55758                    1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 5098                           0.04   1  2008                        9.35508
# 5099                          0.038   1  2008                        8.37088
# 5100                          0.056   1  2008                        8.18958
# 5101                           0.03   1  2008                        9.48458
# 5102                          0.041   1  2008                        8.80082
# ...                             ...  ..   ...                            ...
# 55754                         0.069  12  2012                        9.79538
# 55755                          0.02  12  2012                       10.25640
# 55756                             -  12  2012                       10.37554
# 55757                         0.152  12  2012                        8.27764
# 55758                         0.133  12  2012                        9.56746
#
# [19576 rows x 21 columns]

# %% [markdown]
# ##### ALTERNATIVA 3
#
# lista_de_anos
#
# [2008, 2010, 2012]

# %%
data.query('ANO in @lista_de_anos')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 5098                   0.29                    0.045
# 5099                  0.293                    0.062
# 5100                  0.278                    0.060
# 5101                  0.382                    0.025
# 5102                  0.199                    0.058
# ...                     ...                      ...
# 55754                 0.466                    0.008
# 55755                 0.566                    0.020
# 55756                     -                    0.017
# 55757                 0.397                    0.125
# 55758                 0.504                    0.018
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                      1.516                      0.061
# 5099                      1.323                       0.05
# 5100                      1.303                      0.073
# 5101                      1.449                      0.044
# 5102                        1.5                      0.062
# ...                         ...                        ...
# 55754                     1.425                      0.098
# 55755                     1.414                      0.028
# 55756                         -                          -
# 55757                     1.201                      0.182
# 55758                     1.343                      0.178
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                     1.3892                    1.6157
# 5099                     1.2242                    1.6173
# 5100                       1.14                      1.45
# 5101                     1.3247                    1.5514
# 5102                       1.39                    1.7689
# ...                         ...                       ...
# 55754                    1.2657                    1.4789
# 55755                    1.3997                    1.4608
# 55756                         -                         -
# 55757                    0.8354                     1.535
# 55758                    1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 5098                           0.04   1  2008                        9.35508
# 5099                          0.038   1  2008                        8.37088
# 5100                          0.056   1  2008                        8.18958
# 5101                           0.03   1  2008                        9.48458
# 5102                          0.041   1  2008                        8.80082
# ...                             ...  ..   ...                            ...
# 55754                         0.069  12  2012                        9.79538
# 55755                          0.02  12  2012                       10.25640
# 55756                             -  12  2012                       10.37554
# 55757                         0.152  12  2012                        8.27764
# 55758                         0.133  12  2012                        9.56746
#
# [19576 rows x 21 columns]

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
data.head(10)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                 1.190  ...
# 1                1.162                  0.114                 0.890  ...
# 2                1.389                  0.097                 1.180  ...
# 3                1.262                  0.070                 1.090  ...
# 4                1.181                  0.078                 1.050  ...
# 5                1.383                  0.132                 0.999  ...
# 6                1.453                  0.218                 1.030  ...
# 7                1.631                  0.158                 1.350  ...
# 8                1.284                  0.130                 1.100  ...
# 9                1.224                  0.141                 0.989  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
# 6                 0.353                    0.150                       1.1
# 7                 0.515                    0.097                     1.116
# 8                 0.353                    0.101                     0.931
# 9                 0.277                    0.115                     0.947
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
# 6                      0.068                    0.7332
# 7                      0.091                    0.9923
# 8                      0.072                    0.7577
# 9                      0.091                    0.5643
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
# 6                     1.294                         0.062   5  2004
# 7                   1.36183                         0.082   5  2004
# 8                    1.2972                         0.077   5  2004
# 9                    1.3541                         0.096   5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
# 5                        7.16394
# 6                        7.52654
# 7                        8.44858
# 8                        6.65112
# 9                        6.34032
#
# [10 rows x 21 columns]

# %%
for index, row in data.head(10).iterrows():
    print(f'Índice: {index} ==> {row["ESTADO"]}')
# Out:
# Índice: 0 ==> DISTRITO FEDERAL
# Índice: 1 ==> GOIAS
# Índice: 2 ==> MATO GROSSO
# Índice: 3 ==> MATO GROSSO DO SUL
# Índice: 4 ==> ALAGOAS
# Índice: 5 ==> BAHIA
# Índice: 6 ==> CEARA
# Índice: 7 ==> MARANHAO
# Índice: 8 ==> PARAIBA
# Índice: 9 ==> PERNAMBUCO

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  str
#  1   DATA FINAL                     106823 non-null  str
#  2   REGIÃO                         106823 non-null  str
#  3   ESTADO                         106823 non-null  str
#  4   PRODUTO                        106823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  str
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  str
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  str
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  str
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  str
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  str
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  str
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  PREÇO MÉDIO REVENDA (dólares)  106823 non-null  float64
# dtypes: float64(6), int64(3), str(12)
# memory usage: 17.1 MB

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[us]
#  1   DATA FINAL                     106823 non-null  datetime64[us]
#  2   REGIÃO                         106823 non-null  str
#  3   ESTADO                         106823 non-null  str
#  4   PRODUTO                        106823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  str
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  str
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  str
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  str
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  str
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  str
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  str
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  PREÇO MÉDIO REVENDA (dólares)  106823 non-null  float64
# dtypes: datetime64[us](2), float64(6), int64(3), str(10)
# memory usage: 17.1 MB

# %% [markdown]
# #### **Dados Numéricos**

# %%
#convertendo atributos/colunas para 'numeric'
for atributo in['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    #converte as colunas de valores string para um tipo númerico
    # em caso de erro na conversão, p. ex. uma string que não represente um numero, um valor vazio (null/nan) será atribuido no lugar
   data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors = 'coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[us]
#  1   DATA FINAL                     106823 non-null  datetime64[us]
#  2   REGIÃO                         106823 non-null  str
#  3   ESTADO                         106823 non-null  str
#  4   PRODUTO                        106823 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  str
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103423 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103423 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103423 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103423 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103423 non-null  float64
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  PREÇO MÉDIO REVENDA (dólares)  106823 non-null  float64
# dtypes: datetime64[us](2), float64(12), int64(3), str(4)
# memory usage: 17.1 MB

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                     NaN                     0.167
# 1958                     NaN                     0.000
# 2012                     NaN                     0.010
# 2497                     NaN                     0.018
# 3199                     NaN                     0.030
# ...                      ...                       ...
# 106664                   NaN                     0.043
# 106666                   NaN                     0.094
# 106811                   NaN                     0.002
# 106813                   NaN                     0.028
# 106815                   NaN                     0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         NaN                         NaN
# 1958                         NaN                         NaN
# 2012                         NaN                         NaN
# 2497                         NaN                         NaN
# 3199                         NaN                         NaN
# ...                          ...                         ...
# 106664                       NaN                         NaN
# 106666                       NaN                         NaN
# 106811                       NaN                         NaN
# 106813                       NaN                         NaN
# 106815                       NaN                         NaN
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          NaN                        NaN
# 1958                          NaN                        NaN
# 2012                          NaN                        NaN
# 2497                          NaN                        NaN
# 3199                          NaN                        NaN
# ...                           ...                        ...
# 106664                        NaN                        NaN
# 106666                        NaN                        NaN
# 106811                        NaN                        NaN
# 106813                        NaN                        NaN
# 106815                        NaN                        NaN
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 1903                              NaN    9  2005
# 1958                              NaN   10  2005
# 2012                              NaN   10  2005
# 2497                              NaN    2  2006
# 3199                              NaN    8  2006
# ...                               ...  ...   ...
# 106664                            NaN    6  2019
# 106666                            NaN    6  2019
# 106811                            NaN    6  2019
# 106813                            NaN    6  2019
# 106815                            NaN    6  2019
#
#         PREÇO MÉDIO REVENDA (dólares)
# 1903                          8.77492
# 1958                         10.36000
# 2012                         11.79486
# 2497                         11.30276
# 3199                         11.83630
# ...                               ...
# 106664                       17.84510
# 106666                       16.22376
# 106811                       17.08882
# 106813                       18.37864
# 106815                       17.04220
#
# [3400 rows x 21 columns]

# %%
#nos dados originais, quais eram os valores do preço médio distribuição dos registros que agora são nan
data[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 1903                       -                    0.167
# 1958                       -                    0.000
# 2012                       -                    0.010
# 2497                       -                    0.018
# 3199                       -                    0.030
# ...                      ...                      ...
# 106664                     -                    0.043
# 106666                     -                    0.094
# 106811                     -                    0.002
# 106813                     -                    0.028
# 106815                     -                    0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                           -                          -
# 1958                           -                          -
# 2012                           -                          -
# 2497                           -                          -
# 3199                           -                          -
# ...                          ...                        ...
# 106664                         -                          -
# 106666                         -                          -
# 106811                         -                          -
# 106813                         -                          -
# 106815                         -                          -
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                           -                         -
# 1958                           -                         -
# 2012                           -                         -
# 2497                           -                         -
# 3199                           -                         -
# ...                          ...                       ...
# 106664                         -                         -
# 106666                         -                         -
# 106811                         -                         -
# 106813                         -                         -
# 106815                         -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 1903                               -   9  2005                        8.77492
# 1958                               -  10  2005                       10.36000
# 2012                               -  10  2005                       11.79486
# 2497                               -   2  2006                       11.30276
# 3199                               -   8  2006                       11.83630
# ...                              ...  ..   ...                            ...
# 106664                             -   6  2019                       17.84510
# 106666                             -   6  2019                       16.22376
# 106811                             -   6  2019                       17.08882
# 106813                             -   6  2019                       18.37864
# 106815                             -   6  2019                       17.04220
#
# [3400 rows x 21 columns]

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
#retorna uma cópia do data frame 'data_pre' com todos os valores NaN de todas as colunas agora preenchidas com 0
#para alterar o data frame original usar Inplace = True
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                      0.240                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                 0.950                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                       0.000
# 106819                     2.451                       0.402
# 106820                     1.998                       0.000
# 106821                     2.374                       0.165
# 106822                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 106818                     2.7560                    2.75600
# 106819                     1.9842                    2.86610
# 106820                     1.9981                    1.99810
# 106821                     2.0179                    2.50930
# 106822                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 106818                          0.000    6  2019
# 106819                          0.164    6  2019
# 106820                          0.000    6  2019
# 106821                          0.070    6  2019
# 106822                          0.000    6  2019
#
#         PREÇO MÉDIO REVENDA (dólares)
# 0                             6.67184
# 1                             6.01916
# 2                             7.19502
# 3                             6.53716
# 4                             6.11758
# ...                               ...
# 106818                       18.51332
# 106819                       17.61718
# 106820                       15.08416
# 106821                       15.64360
# 106822                       19.15046
#
# [106823 rows x 21 columns]

# %%
#valores que antes era NaN agora são 0
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                     0.0                     0.167
# 1958                     0.0                     0.000
# 2012                     0.0                     0.010
# 2497                     0.0                     0.018
# 3199                     0.0                     0.030
# ...                      ...                       ...
# 106664                   0.0                     0.043
# 106666                   0.0                     0.094
# 106811                   0.0                     0.002
# 106813                   0.0                     0.028
# 106815                   0.0                     0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         0.0                         0.0
# 1958                         0.0                         0.0
# 2012                         0.0                         0.0
# 2497                         0.0                         0.0
# 3199                         0.0                         0.0
# ...                          ...                         ...
# 106664                       0.0                         0.0
# 106666                       0.0                         0.0
# 106811                       0.0                         0.0
# 106813                       0.0                         0.0
# 106815                       0.0                         0.0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          0.0                        0.0
# 1958                          0.0                        0.0
# 2012                          0.0                        0.0
# 2497                          0.0                        0.0
# 3199                          0.0                        0.0
# ...                           ...                        ...
# 106664                        0.0                        0.0
# 106666                        0.0                        0.0
# 106811                        0.0                        0.0
# 106813                        0.0                        0.0
# 106815                        0.0                        0.0
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 1903                              0.0    9  2005
# 1958                              0.0   10  2005
# 2012                              0.0   10  2005
# 2497                              0.0    2  2006
# 3199                              0.0    8  2006
# ...                               ...  ...   ...
# 106664                            0.0    6  2019
# 106666                            0.0    6  2019
# 106811                            0.0    6  2019
# 106813                            0.0    6  2019
# 106815                            0.0    6  2019
#
#         PREÇO MÉDIO REVENDA (dólares)
# 1903                          8.77492
# 1958                         10.36000
# 2012                         11.79486
# 2497                         11.30276
# 3199                         11.83630
# ...                               ...
# 106664                       17.84510
# 106666                       16.22376
# 106811                       17.08882
# 106813                       18.37864
# 106815                       17.04220
#
# [3400 rows x 21 columns]

# %%
#retorna uma cópia do data frame 'data_pre' com todos os valores NaN das colunas:
#'PREÇO MÉDIO DISTRIBUIÇÃO, 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO' E 'PREÇO MÁXIMO DISTRIBUIÇÃO', respetivamente 
data_pre_fill = data_pre.fillna(value = {
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO':30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio'
})
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                      0.240                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                 0.950                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                       0.000
# 106819                     2.451                       0.402
# 106820                     1.998                       0.000
# 106821                     2.374                       0.165
# 106822                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                     0.9666
# 1                          0.5013                       1.05
# 2                          0.5614                      1.161
# 3                          0.5991                    1.22242
# 4                          0.7441                     1.0317
# ...                           ...                        ...
# 106818                     2.7560                      2.756
# 106819                     1.9842                     2.8661
# 106820                     1.9981                     1.9981
# 106821                     2.0179                     2.5093
# 106822                     2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 0                              0.133    5  2004                        6.67184
# 1                              0.115    5  2004                        6.01916
# 2                              0.098    5  2004                        7.19502
# 3                              0.143    5  2004                        6.53716
# 4                              0.082    5  2004                        6.11758
# ...                              ...  ...   ...                            ...
# 106818                         0.000    6  2019                       18.51332
# 106819                         0.164    6  2019                       17.61718
# 106820                         0.000    6  2019                       15.08416
# 106821                         0.070    6  2019                       15.64360
# 106822                         0.000    6  2019                       19.15046
#
# [106823 rows x 21 columns]

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                     NaN                     0.167
# 1958                     NaN                     0.000
# 2012                     NaN                     0.010
# 2497                     NaN                     0.018
# 3199                     NaN                     0.030
# ...                      ...                       ...
# 106664                   NaN                     0.043
# 106666                   NaN                     0.094
# 106811                   NaN                     0.002
# 106813                   NaN                     0.028
# 106815                   NaN                     0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                        10.0                        20.0
# 1958                        10.0                        20.0
# 2012                        10.0                        20.0
# 2497                        10.0                        20.0
# 3199                        10.0                        20.0
# ...                          ...                         ...
# 106664                      10.0                        20.0
# 106666                      10.0                        20.0
# 106811                      10.0                        20.0
# 106813                      10.0                        20.0
# 106815                      10.0                        20.0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                         30.0                      vazio
# 1958                         30.0                      vazio
# 2012                         30.0                      vazio
# 2497                         30.0                      vazio
# 3199                         30.0                      vazio
# ...                           ...                        ...
# 106664                       30.0                      vazio
# 106666                       30.0                      vazio
# 106811                       30.0                      vazio
# 106813                       30.0                      vazio
# 106815                       30.0                      vazio
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 1903                             NaN    9  2005                        8.77492
# 1958                             NaN   10  2005                       10.36000
# 2012                             NaN   10  2005                       11.79486
# 2497                             NaN    2  2006                       11.30276
# 3199                             NaN    8  2006                       11.83630
# ...                              ...  ...   ...                            ...
# 106664                           NaN    6  2019                       17.84510
# 106666                           NaN    6  2019                       16.22376
# 106811                           NaN    6  2019                       17.08882
# 106813                           NaN    6  2019                       18.37864
# 106815                           NaN    6  2019                       17.04220
#
# [3400 rows x 21 columns]

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
#remove no proprio dataframe todas as linhas/registros com valores NaN (vazios) em qualquer coluna/atributos.
data_pre.dropna(inplace=True)

# %%
data_pre.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103392 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[us]
#  1   DATA FINAL                     103392 non-null  datetime64[us]
#  2   REGIÃO                         103392 non-null  str
#  3   ESTADO                         103392 non-null  str
#  4   PRODUTO                        103392 non-null  str
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  str
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  18  MÊS                            103392 non-null  int64
#  19  ANO                            103392 non-null  int64
#  20  PREÇO MÉDIO REVENDA (dólares)  103392 non-null  float64
# dtypes: datetime64[us](2), float64(12), int64(3), str(4)
# memory usage: 17.4 MB

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
data_pre.to_csv('./dataset/GasPricesinBrazil_2004-2019_preprocessado_final.csv', index = False)

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %%
data_final = pd.read_csv('./dataset/GasPricesinBrazil_2004-2019_preprocessado_final.csv')

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103387               GNV                             7             R$/m3
# 103388               GNV                            23             R$/m3
# 103389               GNV                            24             R$/m3
# 103390               GNV                            52             R$/m3
# 103391               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 103387                3.574                  0.065                 3.499  ...
# 103388                3.401                  0.129                 3.230  ...
# 103389                2.912                  0.190                 2.699  ...
# 103390                3.020                  0.229                 2.699  ...
# 103391                3.697                  0.005                 3.689  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                      0.240                     0.066
# ...                      ...                       ...
# 103387                 0.818                     0.018
# 103388                 0.950                     0.038
# 103389                 0.914                     0.065
# 103390                 0.646                     0.076
# 103391                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 103387                          0.000    6  2019
# 103388                          0.164    6  2019
# 103389                          0.000    6  2019
# 103390                          0.070    6  2019
# 103391                          0.000    6  2019
#
#         PREÇO MÉDIO REVENDA (dólares)
# 0                             6.67184
# 1                             6.01916
# 2                             7.19502
# 3                             6.53716
# 4                             6.11758
# ...                               ...
# 103387                       18.51332
# 103388                       17.61718
# 103389                       15.08416
# 103390                       15.64360
# 103391                       19.15046
#
# [103392 rows x 21 columns]

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        PREÇO MÉDIO REVENDA (dólares)
# count                  103392.000000
# mean                       55.863567
# std                        91.612711
# min                         3.967880
# 25%                        10.738140
# 50%                        14.105140
# 75%                        19.399100
# max                       514.669260

# %%
data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = data_final.describe()
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        PREÇO MÉDIO REVENDA (dólares)
# count                  103392.000000
# mean                       55.863567
# std                        91.612711
# min                         3.967880
# 25%                        10.738140
# 50%                        14.105140
# 75%                        19.399100
# max                       514.669260

# %%
stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
data_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        PREÇO MÉDIO REVENDA (dólares)
# count                  103392.000000
# mean                       55.863567
# std                        91.612711
# min                         3.967880
# 25%                        10.738140
# 50%                        14.105140
# 75%                        19.399100
# max                       514.669260

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min                       1.000000             0.766000
# max                    4167.000000            99.357000
# mean                    240.511935            10.784472
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000             90.000000            120.000000
# mean               0.652589              9.334931             12.458686
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min               0.001000                  0.000000
# max              36.847000                  0.262000
# mean              2.225151                  0.045749
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min                   0.506000                    0.000000
# max                  83.137000                   18.385000
# mean                  8.559322                    0.559441
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# min                    0.325700                   0.599200
# max                   83.000000                  94.500000
# mean                   7.414814                   9.805621
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO        MÊS          ANO  \
# min                         0.00000   1.000000  2004.000000
# max                         0.78000  12.000000  2019.000000
# mean                        0.04664   6.485067  2011.737001
#
#       PREÇO MÉDIO REVENDA (dólares)
# min                        3.967880
# max                      514.669260
# mean                      55.863567

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# np.float64(0.59)

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é {mean:.2f} +- {std:.2f}')
# Out:
# A média dos preços mínimos de revenda é 9.33 +- 15.02

# %% [markdown]
# #### Quais são os estados considerados?

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: str

# %%
estados = data_final['ESTADO'].unique()
print(f'Os estados são: {estados}')
# Out:
# Os estados são: <StringArray>
# [   'DISTRITO FEDERAL',               'GOIAS',         'MATO GROSSO',
#   'MATO GROSSO DO SUL',             'ALAGOAS',               'BAHIA',
#                'CEARA',            'MARANHAO',             'PARAIBA',
#           'PERNAMBUCO',               'PIAUI', 'RIO GRANDE DO NORTE',
#              'SERGIPE',                'ACRE',               'AMAPA',
#             'AMAZONAS',                'PARA',            'RONDONIA',
#              'RORAIMA',           'TOCANTINS',      'ESPIRITO SANTO',
#         'MINAS GERAIS',      'RIO DE JANEIRO',           'SAO PAULO',
#               'PARANA',   'RIO GRANDE DO SUL',      'SANTA CATARINA']
# Length: 27, dtype: str

# %%
sorted(estados)
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final['ESTADO'].value_counts() #retorna em ordem decrescente a quantidade de registros/linhas para cada estado
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame() #converte a series pra um DataFrame
# Out:
#                      count
# ESTADO
# BAHIA                 4263
# RIO DE JANEIRO        4262
# SAO PAULO             4261
# RIO GRANDE DO SUL     4249
# PARAIBA               4240
# PERNAMBUCO            4236
# SERGIPE               4202
# SANTA CATARINA        4164
# MINAS GERAIS          4142
# ESPIRITO SANTO        4079
# MATO GROSSO DO SUL    4076
# ALAGOAS               4020
# RIO GRANDE DO NORTE   3999
# CEARA                 3964
# PARANA                3902
# AMAZONAS              3713
# MATO GROSSO           3703
# PARA                  3477
# MARANHAO              3470
# ACRE                  3463
# RORAIMA               3457
# TOCANTINS             3453
# GOIAS                 3449
# RONDONIA              3441
# PIAUI                 3394
# DISTRITO FEDERAL      3317
# AMAPA                 2996

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(linha):
    return linha.sum()#retorna a soma de todos valores de uma linha

# %%
df['SOMA(A,B,C)'] = df.apply(nossa_soma, axis = 1)
df
# Out:
#          A   B    C  SOMA(A,B,C)
# Linha 1  1  10  100          111
# Linha 2  2  20  200          222
# Linha 3  3  30  300          333
# Linha 4  4  40  400          444

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.loc['Linha 5'] = df.apply(nossa_soma, axis = 0)
df
# Out:
#           A    B     C  SOMA(A,B,C)
# Linha 1   1   10   100          111
# Linha 2   2   20   200          222
# Linha 3   3   30   300          333
# Linha 4   4   40   400          444
# Linha    10  100  1000         1110
# Linha 5  40  400  4000         4440

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Usando `lambda` functions

# %%
df['MEDIA (A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis = 1)
df
# Out:
#           A    B     C  SOMA(A,B,C)  MEDIA (A, B, C)
# Linha 1   1   10   100          111             37.0
# Linha 2   2   20   200          222             74.0
# Linha 3   3   30   300          333            111.0
# Linha 4   4   40   400          444            148.0
# Linha    10  100  1000         1110            370.0
# Linha 5  40  400  4000         4440           1480.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Aplica a lambda function abaixo para cada elemento da coluna
df['C*2']=df['C'].apply(lambda x: x*2)
df
# Out:
#           A    B     C  SOMA(A,B,C)  MEDIA (A, B, C)   C*2
# Linha 1   1   10   100          111             37.0   200
# Linha 2   2   20   200          222             74.0   400
# Linha 3   3   30   300          333            111.0   600
# Linha 4   4   40   400          444            148.0   800
# Linha    10  100  1000         1110            370.0  2000
# Linha 5  40  400  4000         4440           1480.0  8000

# %%
df['A*2']=df['A']*2
df
# Out:
#          A   B    C  A*2
# Linha 1  1  10  100    2
# Linha 2  2  20  200    4
# Linha 3  3  30  300    6
# Linha 4  4  40  400    8

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
#retorna um novo dataframa com todos os elementos ao quadrado.
#poderiamos usar uma função ao invés de uma lambda function
df.apply(lambda x: x**2)
# Out:
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
nomes = pd.Series(['João', 'Maria', 'Alice', 'Pedro'])
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: str

# %%
#retorna uma nova Series com todos os nomes com letras maiuscúlas
#poderiamos usar uma função ao invés de uma labda function
nomes.map(lambda x: x.upper())
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: str

# %%
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: str

# %%
#O pandas já fornece uma série de métodos pra manipulação de strings.
#Assim, poderiamos usar o mesmo código abaixo para obter o mesmo resultado.
nomes.str.upper()
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: str

# %%
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: str

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %%
#AGRUPA AS LINHAS DA TABELA DE ACORDO COM SUAS RESPECTIVAS REGIÕES
grupos = data_final.groupby('REGIÃO')
grupos

# %%
#retorna os grupos obtivos pelo groupby
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
#retorna os indices das linhas/observações de cada grupo
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 103363, 103364, 103383],
#        shape=(14545,)),
#  'NORDESTE': array([     4,      5,      6, ..., 103385, 103387, 103391],
#        shape=(35788,)),
#  'NORTE': array([    13,     14,     15, ..., 103374, 103375, 103379],
#        shape=(24000,)),
#  'SUDESTE': array([    20,     21,     22, ..., 103377, 103386, 103390],
#        shape=(16744,)),
#  'SUL': array([    24,     25,     26, ..., 103376, 103388, 103389],
#        shape=(12315,))}

# %%
#retorna um dataframe apenas com observações do grupo 'CENTRO OESTE'
grupos.get_group('CENTRO OESTE')
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 27       2004-05-16  2004-05-22  CENTRO OESTE    DISTRITO FEDERAL
# ...             ...         ...           ...                 ...
# 103359   2019-06-23  2019-06-29  CENTRO OESTE    DISTRITO FEDERAL
# 103361   2019-06-23  2019-06-29  CENTRO OESTE               GOIAS
# 103363   2019-06-23  2019-06-29  CENTRO OESTE         MATO GROSSO
# 103364   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
# 103383   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 27      ETANOL HIDRATADO                           144              R$/l
# ...                  ...                           ...               ...
# 103359               GLP                            42           R$/13Kg
# 103361               GLP                           209           R$/13Kg
# 103363               GLP                            95           R$/13Kg
# 103364               GLP                           115           R$/13Kg
# 103383               GNV                             2             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 27                    1.271                  0.039                 1.060  ...
# ...                     ...                    ...                   ...  ...
# 103359               73.452                  4.875                65.000  ...
# 103361               71.968                  5.381                53.000  ...
# 103363               96.691                  6.835                73.000  ...
# 103364               72.297                  8.054                59.990  ...
# 103383                2.934                  0.049                 2.899  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 27                     0.448                     0.031
# ...                      ...                       ...
# 103359                21.509                     0.066
# 103361                15.044                     0.075
# 103363                19.789                     0.071
# 103364                16.707                     0.111
# 103383                 0.901                     0.017
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 27                         0.823                       0.111
# ...                          ...                         ...
# 103359                    51.943                       7.877
# 103361                    56.924                       4.285
# 103363                    76.902                       8.846
# 103364                    55.590                       5.109
# 103383                     2.033                       0.259
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 27                         0.4094                    1.19310
# ...                           ...                        ...
# 103359                    44.0000                   62.82000
# 103361                    45.5700                   61.60000
# 103363                    61.1500                   90.00000
# 103364                    47.0000                   72.00000
# 103383                     1.8500                    2.21610
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 27                              0.135    5  2004
# ...                               ...  ...   ...
# 103359                          0.152    6  2019
# 103361                          0.075    6  2019
# 103363                          0.115    6  2019
# 103364                          0.092    6  2019
# 103383                          0.127    6  2019
#
#         PREÇO MÉDIO REVENDA (dólares)
# 0                             6.67184
# 1                             6.01916
# 2                             7.19502
# 3                             6.53716
# 27                            6.58378
# ...                               ...
# 103359                      380.48136
# 103361                      372.79424
# 103363                      500.85938
# 103364                      374.49846
# 103383                       15.19812
#
# [14545 rows x 21 columns]

# %%
#descreva para nós algumas estatísticas descritivas para as observações de cada grupo
grupos.describe()

# %%
grupos.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[468], line 1
# ----> 1 grupos.mean()
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/internals/managers.py:1646, in BlockManager.grouped_reduce(self, func)
#    1644             result_blocks = extend_blocks(applied, result_blocks)
#    1645     else:
# -> 1646         applied = blk.apply(func)
#    1647         result_blocks = extend_blocks(applied, result_blocks)
#    1649 if len(result_blocks) == 0:
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/internals/blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/arrays/base.py:2807, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2793 if isinstance(self.dtype, StringDtype):
#    2794     # StringArray
#    2795     if op.how in [
#    2796         "prod",
#    2797         "mean",
#    (...)   2805         "kurt",
#    2806     ]:
# -> 2807         raise TypeError(
#    2808             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2809         )
#    2810     if op.how not in ["any", "all"]:
#    2811         # Fail early to avoid conversion to object
#    2812         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %%
grupos.min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# NORDESTE                    0.975                    0.0
# NORTE                       1.226                    0.0
# SUDESTE                     0.766                    0.0
# SUL                         0.922                    0.0
#
#               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO
# CENTRO OESTE                  0.87                 1.099
# NORDESTE                      0.79                 0.999
# NORTE                         1.05                 1.300
# SUDESTE                       0.59                 1.099
# SUL                           0.73                 1.199
#
#               MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                 0.031                       0.0
# NORDESTE                     0.039                       0.0
# NORTE                        0.022                       0.0
# SUDESTE                      0.001                       0.0
# SUL                          0.025                       0.0
#
#               PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                     0.737                         0.0
# NORDESTE                         0.586                         0.0
# NORTE                            0.674                         0.0
# SUDESTE                          0.506                         0.0
# SUL                              0.667                         0.0
#
#               PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                    0.38790                     0.8359
# NORDESTE                        0.36320                     0.5992
# NORTE                           0.51022                     0.9612
# SUDESTE                         0.32570                     0.7822
# SUL                             0.43000                     0.7044
#
#               COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# REGIÃO
# CENTRO OESTE                            0.0    1  2004
# NORDESTE                                0.0    1  2004
# NORTE                                   0.0    1  2004
# SUDESTE                                 0.0    1  2004
# SUL                                     0.0    1  2004
#
#               PREÇO MÉDIO REVENDA (dólares)
# REGIÃO
# CENTRO OESTE                        5.68246
# NORDESTE                            5.05050
# NORTE                               6.35068
# SUDESTE                             3.96788
# SUL                                 4.77596

# %%
data_final.groupby('REGIÃO').min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# NORDESTE                    0.975                    0.0
# NORTE                       1.226                    0.0
# SUDESTE                     0.766                    0.0
# SUL                         0.922                    0.0
#
#               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO
# CENTRO OESTE                  0.87                 1.099
# NORDESTE                      0.79                 0.999
# NORTE                         1.05                 1.300
# SUDESTE                       0.59                 1.099
# SUL                           0.73                 1.199
#
#               MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                 0.031                       0.0
# NORDESTE                     0.039                       0.0
# NORTE                        0.022                       0.0
# SUDESTE                      0.001                       0.0
# SUL                          0.025                       0.0
#
#               PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                     0.737                         0.0
# NORDESTE                         0.586                         0.0
# NORTE                            0.674                         0.0
# SUDESTE                          0.506                         0.0
# SUL                              0.667                         0.0
#
#               PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                    0.38790                     0.8359
# NORDESTE                        0.36320                     0.5992
# NORTE                           0.51022                     0.9612
# SUDESTE                         0.32570                     0.7822
# SUL                             0.43000                     0.7044
#
#               COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# REGIÃO
# CENTRO OESTE                            0.0    1  2004
# NORDESTE                                0.0    1  2004
# NORTE                                   0.0    1  2004
# SUDESTE                                 0.0    1  2004
# SUL                                     0.0    1  2004
#
#               PREÇO MÉDIO REVENDA (dólares)
# REGIÃO
# CENTRO OESTE                        5.68246
# NORDESTE                            5.05050
# NORTE                               6.35068
# SUDESTE                             3.96788
# SUL                                 4.77596

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Qual é o preços médios de cada um dos Produtos (Combustíveis) para cada Região?

# %%
#Agrupa os registros do dataframe primeiramente por suas regiões.
#Então, agrupa os registros de cada região(grupo) de acordo com seus produtos
grupos = data_final.groupby(['REGIÃO', 'PRODUTO'])
grupos

# %%
grupos.groups
# Out:
# {('CENTRO OESTE',
#   'ETANOL HIDRATADO'): Index([     0,      1,      2,      3,     27,     28,     29,     30,     54,
#             55,
#         ...
#         102963, 102964, 103105, 103107, 103109, 103110, 103251, 103253, 103255,
#         103256],
#        dtype='int64', length=3122),
#  ('CENTRO OESTE',
#   'GASOLINA COMUM'): Index([ 11980,  11981,  11982,  11983,  12007,  12008,  12009,  12010,  12034,
#          12035,
#         ...
#         103044, 103045, 103186, 103188, 103190, 103191, 103332, 103334, 103336,
#         103337],
#        dtype='int64', length=3134),
#  ('CENTRO OESTE',
#   'GLP'): Index([ 24019,  24020,  24021,  24022,  24046,  24047,  24048,  24049,  24073,
#          24074,
#         ...
#         103071, 103072, 103213, 103215, 103217, 103218, 103359, 103361, 103363,
#         103364],
#        dtype='int64', length=3098),
#  ('CENTRO OESTE',
#   'GNV'): Index([ 35892,  35907,  35922,  35937,  35952,  35967,  35982,  35997,  36012,
#          36027,
#         ...
#         101769, 102063, 102210, 102504, 102651, 102797, 102945, 103092, 103237,
#         103383],
#        dtype='int64', length=847),
#  ('CENTRO OESTE',
#   'ÓLEO DIESEL'): Index([ 42612,  42613,  42614,  42615,  42639,  42640,  42641,  42642,  42666,
#          42667,
#         ...
#         102990, 102991, 103132, 103134, 103136, 103137, 103278, 103280, 103282,
#         103283],
#        dtype='int64', length=3134),
#  ('CENTRO OESTE',
#   'ÓLEO DIESEL S10'): Index([ 54834,  54835,  54973,  54975,  54976,  55117,  55119,  55120,  55260,
#          55262,
#         ...
#         103017, 103018, 103159, 103161, 103163, 103164, 103305, 103307, 103309,
#         103310],
#        dtype='int64', length=1210),
#  ('NORDESTE',
#   'ETANOL HIDRATADO'): Index([     4,      5,      6,      7,      8,      9,     10,     11,     12,
#             31,
#         ...
#         103124, 103247, 103249, 103250, 103254, 103259, 103261, 103262, 103264,
#         103270],
#        dtype='int64', length=7046),
#  ('NORDESTE',
#   'GASOLINA COMUM'): Index([ 11984,  11985,  11986,  11987,  11988,  11989,  11990,  11991,  11992,
#          12011,
#         ...
#         103205, 103327, 103330, 103331, 103335, 103340, 103342, 103343, 103345,
#         103351],
#        dtype='int64', length=7063),
#  ('NORDESTE',
#   'GLP'): Index([ 24023,  24024,  24025,  24026,  24027,  24028,  24029,  24030,  24031,
#          24050,
#         ...
#         103232, 103354, 103357, 103358, 103362, 103367, 103369, 103370, 103372,
#         103378],
#        dtype='int64', length=6410),
#  ('NORDESTE',
#   'GNV'): Index([ 35893,  35894,  35895,  35896,  35897,  35898,  35899,  35908,  35909,
#          35910,
#         ...
#         103239, 103241, 103245, 103380, 103381, 103382, 103384, 103385, 103387,
#         103391],
#        dtype='int64', length=5176),
#  ('NORDESTE',
#   'ÓLEO DIESEL'): Index([ 42616,  42617,  42618,  42619,  42620,  42621,  42622,  42623,  42624,
#          42643,
#         ...
#         103151, 103273, 103276, 103277, 103281, 103286, 103288, 103289, 103291,
#         103297],
#        dtype='int64', length=7061),
#  ('NORDESTE',
#   'ÓLEO DIESEL S10'): Index([ 54702,  54703,  54706,  54707,  54829,  54831,  54832,  54833,  54839,
#          54840,
#         ...
#         103178, 103300, 103303, 103304, 103308, 103313, 103315, 103316, 103318,
#         103324],
#        dtype='int64', length=3032),
#  ('NORTE',
#   'ETANOL HIDRATADO'): Index([    13,     14,     15,     16,     17,     18,     19,     40,     41,
#             42,
#         ...
#         103112, 103120, 103121, 103125, 103246, 103248, 103258, 103266, 103267,
#         103271],
#        dtype='int64', length=5177),
#  ('NORTE',
#   'GASOLINA COMUM'): Index([ 11993,  11994,  11995,  11996,  11997,  11998,  11999,  12020,  12021,
#          12022,
#         ...
#         103201, 103202, 103206, 103326, 103328, 103329, 103339, 103347, 103348,
#         103352],
#        dtype='int64', length=5464),
#  ('NORTE',
#   'GLP'): Index([ 24032,  24033,  24034,  24035,  24036,  24037,  24038,  24059,  24060,
#          24061,
#         ...
#         103228, 103229, 103233, 103353, 103355, 103356, 103366, 103374, 103375,
#         103379],
#        dtype='int64', length=5327),
#  ('NORTE',
#   'GNV'): Index([ 36940,  37029,  37045,  37076,  37092,  37108,  37124,  37140,  37156,
#          37172,
#         ...
#          99873, 100453, 100601, 101177, 101472, 102060, 102207, 102356, 102941,
#         103089],
#        dtype='int64', length=243),
#  ('NORTE',
#   'ÓLEO DIESEL'): Index([ 42625,  42626,  42627,  42628,  42629,  42630,  42631,  42652,  42653,
#          42654,
#         ...
#         103147, 103148, 103152, 103272, 103274, 103275, 103285, 103293, 103294,
#         103298],
#        dtype='int64', length=5465),
#  ('NORTE',
#   'ÓLEO DIESEL S10'): Index([ 54705,  54709,  54830,  54837,  54844,  54969,  54978,  54986,  55111,
#          55113,
#         ...
#         103174, 103175, 103179, 103299, 103301, 103302, 103312, 103320, 103321,
#         103325],
#        dtype='int64', length=2324),
#  ('SUDESTE',
#   'ETANOL HIDRATADO'): Index([    20,     21,     22,     23,     47,     48,     49,     50,     74,
#             75,
#         ...
#         102971, 102977, 103106, 103111, 103117, 103123, 103252, 103257, 103263,
#         103269],
#        dtype='int64', length=3137),
#  ('SUDESTE',
#   'GASOLINA COMUM'): Index([ 12000,  12001,  12002,  12003,  12027,  12028,  12029,  12030,  12054,
#          12055,
#         ...
#         103052, 103058, 103187, 103192, 103198, 103204, 103333, 103338, 103344,
#         103350],
#        dtype='int64', length=3140),
#  ('SUDESTE',
#   'GLP'): Index([ 24039,  24040,  24041,  24042,  24066,  24067,  24068,  24069,  24093,
#          24094,
#         ...
#         103079, 103085, 103214, 103219, 103225, 103231, 103360, 103365, 103371,
#         103377],
#        dtype='int64', length=3137),
#  ('SUDESTE',
#   'GNV'): Index([ 35900,  35901,  35902,  35903,  35915,  35916,  35917,  35918,  35930,
#          35931,
#         ...
#         102944, 102948, 102952, 103091, 103095, 103098, 103240, 103244, 103386,
#         103390],
#        dtype='int64', length=2841),
#  ('SUDESTE',
#   'ÓLEO DIESEL'): Index([ 42632,  42633,  42634,  42635,  42659,  42660,  42661,  42662,  42686,
#          42687,
#         ...
#         102998, 103004, 103133, 103138, 103144, 103150, 103279, 103284, 103290,
#         103296],
#        dtype='int64', length=3140),
#  ('SUDESTE',
#   'ÓLEO DIESEL S10'): Index([ 54704,  54711,  54836,  54841,  54846,  54972,  54977,  54983,  54988,
#          55116,
#         ...
#         103025, 103031, 103160, 103165, 103171, 103177, 103306, 103311, 103317,
#         103323],
#        dtype='int64', length=1349),
#  ('SUL',
#   'ETANOL HIDRATADO'): Index([    24,     25,     26,     51,     52,     53,     78,     79,     80,
#            105,
#         ...
#         102828, 102968, 102973, 102976, 103114, 103119, 103122, 103260, 103265,
#         103268],
#        dtype='int64', length=2353),
#  ('SUL',
#   'GASOLINA COMUM'): Index([ 12004,  12005,  12006,  12031,  12032,  12033,  12058,  12059,  12060,
#          12085,
#         ...
#         102909, 103049, 103054, 103057, 103195, 103200, 103203, 103341, 103346,
#         103349],
#        dtype='int64', length=2354),
#  ('SUL',
#   'GLP'): Index([ 24043,  24044,  24045,  24070,  24071,  24072,  24097,  24098,  24099,
#          24124,
#         ...
#         102936, 103076, 103081, 103084, 103222, 103227, 103230, 103368, 103373,
#         103376],
#        dtype='int64', length=2343),
#  ('SUL',
#   'GNV'): Index([ 35904,  35905,  35906,  35919,  35920,  35921,  35934,  35935,  35936,
#          35949,
#         ...
#         102802, 102803, 102950, 102951, 103096, 103097, 103242, 103243, 103388,
#         103389],
#        dtype='int64', length=1899),
#  ('SUL',
#   'ÓLEO DIESEL'): Index([ 42636,  42637,  42638,  42663,  42664,  42665,  42690,  42691,  42692,
#          42717,
#         ...
#         102855, 102995, 103000, 103003, 103141, 103146, 103149, 103287, 103292,
#         103295],
#        dtype='int64', length=2354),
#  ('SUL',
#   'ÓLEO DIESEL S10'): Index([ 54708,  54710,  54838,  54843,  54845,  54980,  54985,  54987,  55124,
#          55129,
#         ...
#         102882, 103022, 103027, 103030, 103168, 103173, 103176, 103314, 103319,
#         103322],
#        dtype='int64', length=1012)}

# %%
grupos.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[472], line 1
# ----> 1 grupos.mean()
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/internals/managers.py:1646, in BlockManager.grouped_reduce(self, func)
#    1644             result_blocks = extend_blocks(applied, result_blocks)
#    1645     else:
# -> 1646         applied = blk.apply(func)
#    1647         result_blocks = extend_blocks(applied, result_blocks)
#    1649 if len(result_blocks) == 0:
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/internals/blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/arrays/base.py:2807, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2793 if isinstance(self.dtype, StringDtype):
#    2794     # StringArray
#    2795     if op.how in [
#    2796         "prod",
#    2797         "mean",
#    (...)   2805         "kurt",
#    2806     ]:
# -> 2807         raise TypeError(
#    2808             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2809         )
#    2810     if op.how not in ["any", "all"]:
#    2811         # Fail early to avoid conversion to object
#    2812         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %%
grupos['PREÇO MÉDIA REVENDA'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[473], line 1
# ----> 1 grupos['PREÇO MÉDIA REVENDA'].mean()
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/groupby/generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# --> 228         raise KeyError(f"Column not found: {key}")
#     229     ndim = self.obj[key].ndim
#     230     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: PREÇO MÉDIA REVENDA'

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3122.0   2.135670   0.561465   1.162   1.71400
#              GASOLINA COMUM    3134.0   3.077476   0.615290   1.936   2.66725
#              GLP               3098.0  48.176747  15.204045  28.791  37.33300
#              GNV                847.0   1.856312   0.423861   1.097   1.56900
#              ÓLEO DIESEL       3134.0   2.481286   0.626930   1.435   2.03300
#              ÓLEO DIESEL S10   1210.0   3.294752   0.421234   2.305   2.92425
# NORDESTE     ETANOL HIDRATADO  7046.0   2.320266   0.604374   1.181   1.82500
#              GASOLINA COMUM    7063.0   3.001887   0.640696   1.949   2.58400
#              GLP               6410.0  41.966090  12.063743  28.367  33.22875
#              GNV               5176.0   1.881722   0.522996   0.975   1.59600
#              ÓLEO DIESEL       7061.0   2.346950   0.605705   1.313   1.90000
#              ÓLEO DIESEL S10   3032.0   3.041966   0.441550   2.130   2.60000
# NORTE        ETANOL HIDRATADO  5177.0   2.511624   0.646781   1.226   2.03300
#              GASOLINA COMUM    5464.0   3.149501   0.641249   1.995   2.70475
#              GLP               5327.0  47.065572  14.553748  28.086  36.32950
#              GNV                243.0   2.084399   0.622229   1.399   1.39900
#              ÓLEO DIESEL       5465.0   2.571048   0.650994   1.450   2.08600
#              ÓLEO DIESEL S10   2324.0   3.316231   0.529044   2.193   2.88300
# SUDESTE      ETANOL HIDRATADO  3137.0   2.163621   0.651486   0.766   1.69200
#              GASOLINA COMUM    3140.0   3.000565   0.698573   1.888   2.50200
#              GLP               3137.0  42.081544  11.524738  28.026  33.63600
#              GNV               2841.0   1.716074   0.462098   0.996   1.42400
#              ÓLEO DIESEL       3140.0   2.339699   0.588641   1.356   1.87600
#              ÓLEO DIESEL S10   1349.0   3.056194   0.418396   2.180   2.65000
# SUL          ETANOL HIDRATADO  2353.0   2.268156   0.702877   0.922   1.72100
#              GASOLINA COMUM    2354.0   2.972569   0.623557   1.961   2.54300
#              GLP               2343.0  43.490318  11.640755  29.440  34.79250
#              GNV               1899.0   1.865612   0.490703   1.168   1.49900
#              ÓLEO DIESEL       2354.0   2.332293   0.527845   1.374   1.95100
#              ÓLEO DIESEL S10   1012.0   2.981775   0.365470   2.151   2.66300
#
#                                    50%       75%     max
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO   2.0005   2.47900   3.598
#              GASOLINA COMUM     2.8565   3.45975   4.963
#              GLP               42.8385  55.90425  99.357
#              GNV                1.7490   2.16800   3.239
#              ÓLEO DIESEL        2.2465   3.01900   4.162
#              ÓLEO DIESEL S10    3.3540   3.61900   4.200
# NORDESTE     ETANOL HIDRATADO   2.1860   2.67000   3.927
#              GASOLINA COMUM     2.7410   3.42450   4.951
#              GLP               36.8550  48.35100  79.630
#              GNV                1.8005   2.01125   3.811
#              ÓLEO DIESEL        2.0820   2.86700   4.010
#              ÓLEO DIESEL S10    3.0865   3.33800   4.027
# NORTE        ETANOL HIDRATADO   2.3390   2.89600   4.102
#              GASOLINA COMUM     2.9330   3.58475   5.362
#              GLP               42.3110  54.07500  87.270
#              GNV                2.0600   2.65000   3.240
#              ÓLEO DIESEL        2.3390   3.08200   4.774
#              ÓLEO DIESEL S10    3.3155   3.65300   4.878
# SUDESTE      ETANOL HIDRATADO   2.0430   2.56700   4.115
#              GASOLINA COMUM     2.7930   3.45150   5.119
#              GLP               38.2800  49.25900  79.192
#              GNV                1.6630   1.90400   3.399
#              ÓLEO DIESEL        2.0825   2.82500   3.994
#              ÓLEO DIESEL S10    3.0910   3.38600   4.080
# SUL          ETANOL HIDRATADO   2.1130   2.60100   4.287
#              GASOLINA COMUM     2.7315   3.34225   4.953
#              GLP               39.9760  48.73350  72.088
#              GNV                1.7020   2.15950   3.476
#              ÓLEO DIESEL        2.0900   2.78450   3.800
#              ÓLEO DIESEL S10    2.9910   3.25200   3.815

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                  [7, 8, 9],
                  [None, None, None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min]) #ignora o NaN
# Out:
#        A    B    C
# sum  NaN  NaN  NaN
# min  1.0  2.0  3.0

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
#computa o menor e maior valor do 'PREÇO MÉDIO REVENDA' para cada região(grupo)
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.226  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by='nota_final', ascending = False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
notas.sort_values(by='nota_final', ascending = False).reset_index(drop=True)
# Out:
#     nome  idade  nota_final
# 0  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending = [False, True]).reset_index(drop=True)
# Out:
#     nome  idade  nota_final
# 0  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending = [False, True], inplace=True)

# %%
notas.reset_index(drop=True)
# Out:
#     nome  idade  nota_final
# 0  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3   João     20         5.0

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    PREÇO MÉDIO REVENDA (dólares)
# 0                        6.67184
# 1                        6.01916
# 2                        7.19502
# 3                        6.53716
# 4                        6.11758
#
# [5 rows x 21 columns]

# %% [markdown]
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
df = data_final.query('ANO != 2019')
df
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                    1.288                  0.016                 1.190  ...
# 1                    1.162                  0.114                 0.890  ...
# 2                    1.389                  0.097                 1.180  ...
# 3                    1.262                  0.070                 1.090  ...
# 4                    1.181                  0.078                 1.050  ...
# ...                    ...                    ...                   ...  ...
# 99734                3.080                  0.262                 2.798  ...
# 99735                3.465                  0.060                 3.370  ...
# 99736                3.402                  0.103                 3.199  ...
# 99737                2.944                  0.124                 2.790  ...
# 99738                2.353                  0.451                 1.999  ...
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                     0.463                     0.012
# 1                     0.399                     0.098
# 2                     0.419                     0.070
# 3                     0.432                     0.055
# 4                     0.240                     0.066
# ...                     ...                       ...
# 99734                 0.699                     0.085
# 99735                 0.759                     0.017
# 99736                 1.296                     0.030
# 99737                 0.670                     0.042
# 99738                 0.467                     0.192
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 0                              0.133    5  2004                        6.67184
# 1                              0.115    5  2004                        6.01916
# 2                              0.098    5  2004                        7.19502
# 3                              0.143    5  2004                        6.53716
# 4                              0.082    5  2004                        6.11758
# ...                              ...  ...   ...                            ...
# 99734                          0.068   12  2018                       15.95440
# 99735                          0.000   12  2018                       17.94870
# 99736                          0.118   12  2018                       17.62236
# 99737                          0.124   12  2018                       15.24992
# 99738                          0.133   12  2018                       12.18854
#
# [99739 rows x 21 columns]

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %%
df.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0          0   2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1          1   2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2          2   2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3          3   2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4          4   2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...      ...          ...         ...           ...                  ...
# 99734  99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735  99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736  99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737  99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738  99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                    1.288                  0.016  ...                 0.463
# 1                    1.162                  0.114  ...                 0.399
# 2                    1.389                  0.097  ...                 0.419
# 3                    1.262                  0.070  ...                 0.432
# 4                    1.181                  0.078  ...                 0.240
# ...                    ...                    ...  ...                   ...
# 99734                3.080                  0.262  ...                 0.699
# 99735                3.465                  0.060  ...                 0.759
# 99736                3.402                  0.103  ...                 1.296
# 99737                2.944                  0.124  ...                 0.670
# 99738                2.353                  0.451  ...                 0.467
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                         0.012                     0.825
# 1                         0.098                     0.763
# 2                         0.070                     0.970
# 3                         0.055                     0.830
# 4                         0.066                     0.941
# ...                         ...                       ...
# 99734                     0.085                     2.381
# 99735                     0.017                     2.706
# 99736                     0.030                     2.106
# 99737                     0.042                     2.274
# 99738                     0.192                     1.886
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                           0.110                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 99734                       0.161                     2.1670
# 99735                       0.000                     2.7059
# 99736                       0.249                     1.8775
# 99737                       0.283                     1.8738
# 99738                       0.250                     1.6400
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                        0.96660                          0.133    5  2004
# 1                        1.05000                          0.115    5  2004
# 2                        1.16100                          0.098    5  2004
# 3                        1.22242                          0.143    5  2004
# 4                        1.03170                          0.082    5  2004
# ...                          ...                            ...  ...   ...
# 99734                    2.86970                          0.068   12  2018
# 99735                    2.70590                          0.000   12  2018
# 99736                    2.37240                          0.118   12  2018
# 99737                    2.27400                          0.124   12  2018
# 99738                    2.33200                          0.133   12  2018
#
#        PREÇO MÉDIO REVENDA (dólares)
# 0                            6.67184
# 1                            6.01916
# 2                            7.19502
# 3                            6.53716
# 4                            6.11758
# ...                              ...
# 99734                       15.95440
# 99735                       17.94870
# 99736                       17.62236
# 99737                       15.24992
# 99738                       12.18854
#
# [99739 rows x 22 columns]

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %%
df.reset_index(drop = True)
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                    1.288                  0.016                 1.190  ...
# 1                    1.162                  0.114                 0.890  ...
# 2                    1.389                  0.097                 1.180  ...
# 3                    1.262                  0.070                 1.090  ...
# 4                    1.181                  0.078                 1.050  ...
# ...                    ...                    ...                   ...  ...
# 99734                3.080                  0.262                 2.798  ...
# 99735                3.465                  0.060                 3.370  ...
# 99736                3.402                  0.103                 3.199  ...
# 99737                2.944                  0.124                 2.790  ...
# 99738                2.353                  0.451                 1.999  ...
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                     0.463                     0.012
# 1                     0.399                     0.098
# 2                     0.419                     0.070
# 3                     0.432                     0.055
# 4                     0.240                     0.066
# ...                     ...                       ...
# 99734                 0.699                     0.085
# 99735                 0.759                     0.017
# 99736                 1.296                     0.030
# 99737                 0.670                     0.042
# 99738                 0.467                     0.192
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 0                              0.133    5  2004                        6.67184
# 1                              0.115    5  2004                        6.01916
# 2                              0.098    5  2004                        7.19502
# 3                              0.143    5  2004                        6.53716
# 4                              0.082    5  2004                        6.11758
# ...                              ...  ...   ...                            ...
# 99734                          0.068   12  2018                       15.95440
# 99735                          0.000   12  2018                       17.94870
# 99736                          0.118   12  2018                       17.62236
# 99737                          0.124   12  2018                       15.24992
# 99738                          0.133   12  2018                       12.18854
#
# [99739 rows x 21 columns]

# %%
df
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                    1.288                  0.016                 1.190  ...
# 1                    1.162                  0.114                 0.890  ...
# 2                    1.389                  0.097                 1.180  ...
# 3                    1.262                  0.070                 1.090  ...
# 4                    1.181                  0.078                 1.050  ...
# ...                    ...                    ...                   ...  ...
# 99734                3.080                  0.262                 2.798  ...
# 99735                3.465                  0.060                 3.370  ...
# 99736                3.402                  0.103                 3.199  ...
# 99737                2.944                  0.124                 2.790  ...
# 99738                2.353                  0.451                 1.999  ...
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                     0.463                     0.012
# 1                     0.399                     0.098
# 2                     0.419                     0.070
# 3                     0.432                     0.055
# 4                     0.240                     0.066
# ...                     ...                       ...
# 99734                 0.699                     0.085
# 99735                 0.759                     0.017
# 99736                 1.296                     0.030
# 99737                 0.670                     0.042
# 99738                 0.467                     0.192
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 0                              0.133    5  2004                        6.67184
# 1                              0.115    5  2004                        6.01916
# 2                              0.098    5  2004                        7.19502
# 3                              0.143    5  2004                        6.53716
# 4                              0.082    5  2004                        6.11758
# ...                              ...  ...   ...                            ...
# 99734                          0.068   12  2018                       15.95440
# 99735                          0.000   12  2018                       17.94870
# 99736                          0.118   12  2018                       17.62236
# 99737                          0.124   12  2018                       15.24992
# 99738                          0.133   12  2018                       12.18854
#
# [99739 rows x 21 columns]

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %%
postos_regiao = df.groupby('PRODUTO')
postos_regiao

# %%
postos_regiao['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       6821
#                  NORTE          5021
#                  SUDESTE        3039
#                  CENTRO OESTE   3022
#                  SUL            2278
# GASOLINA COMUM   NORDESTE       6838
#                  NORTE          5289
#                  SUDESTE        3040
#                  CENTRO OESTE   3034
#                  SUL            2279
# GLP              NORDESTE       6185
#                  NORTE          5152
#                  SUDESTE        3037
#                  CENTRO OESTE   2998
#                  SUL            2268
# GNV              NORDESTE       5030
#                  SUDESTE        2772
#                  SUL            1847
#                  CENTRO OESTE    825
#                  NORTE           233
# ÓLEO DIESEL      NORDESTE       6836
#                  NORTE          5290
#                  SUDESTE        3040
#                  CENTRO OESTE   3034
#                  SUL            2279
# ÓLEO DIESEL S10  NORDESTE       2807
#                  NORTE          2149
#                  SUDESTE        1249
#                  CENTRO OESTE   1110
#                  SUL             937

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
gasolina_comum_sp = (df['PRODUTO'] == 'GASOLINA COMUM') & (df['ESTADO']== 'SAO PAULO')
df[gasolina_comum_sp]
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 12003   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  GASOLINA COMUM
# 12030   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  GASOLINA COMUM
# 12057   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  GASOLINA COMUM
# 12084   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  GASOLINA COMUM
# 12111   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  GASOLINA COMUM
# ...            ...         ...      ...        ...             ...
# 99122   2018-12-02  2018-12-08  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99266   2018-12-09  2018-12-15  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12003                          4107              R$/l                1.891
# 12030                          4133              R$/l                1.888
# 12057                          4139              R$/l                1.894
# 12084                          4139              R$/l                1.912
# 12111                          4138              R$/l                1.919
# ...                             ...               ...                  ...
# 99122                          1648              R$/l                4.187
# 99266                          1649              R$/l                4.148
# 99410                          1637              R$/l                4.129
# 99553                          1641              R$/l                4.129
# 99698                          1643              R$/l                4.113
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 12003                  0.101                 1.570  ...                 0.235
# 12030                  0.101                 1.540  ...                 0.233
# 12057                  0.095                 1.570  ...                 0.234
# 12084                  0.094                 1.529  ...                 0.235
# 12111                  0.088                 1.580  ...                 0.231
# ...                      ...                   ...  ...                   ...
# 99122                  0.213                 3.699  ...                 0.565
# 99266                  0.212                 3.669  ...                 0.533
# 99410                  0.201                 3.699  ...                 0.490
# 99553                  0.201                 3.699  ...                 0.484
# 99698                  0.201                 3.599  ...                 0.503
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 12003                     0.053                     1.656
# 12030                     0.053                     1.655
# 12057                     0.050                     1.660
# 12084                     0.049                     1.677
# 12111                     0.046                     1.688
# ...                         ...                       ...
# 99122                     0.051                     3.622
# 99266                     0.051                     3.615
# 99410                     0.049                     3.639
# 99553                     0.049                     3.645
# 99698                     0.049                     3.610
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 12003                       0.064                       1.38
# 12030                       0.063                       1.38
# 12057                       0.065                       1.39
# 12084                       0.068                       1.39
# 12111                       0.063                       1.41
# ...                           ...                        ...
# 99122                       0.117                       3.34
# 99266                       0.119                       3.34
# 99410                       0.110                       3.35
# 99553                       0.107                       3.35
# 99698                       0.100                       3.35
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 12003                     1.9440                          0.039    5  2004
# 12030                     1.9319                          0.038    5  2004
# 12057                     1.9291                          0.039    5  2004
# 12084                     1.9733                          0.041    5  2004
# 12111                     2.0946                          0.037    6  2004
# ...                          ...                            ...  ...   ...
# 99122                     4.0849                          0.032   12  2018
# 99266                     4.0849                          0.033   12  2018
# 99410                     3.9892                          0.030   12  2018
# 99553                     3.9892                          0.029   12  2018
# 99698                     3.9585                          0.028   12  2018
#
#        PREÇO MÉDIO REVENDA (dólares)
# 12003                        9.79538
# 12030                        9.77984
# 12057                        9.81092
# 12084                        9.90416
# 12111                        9.94042
# ...                              ...
# 99122                       21.68866
# 99266                       21.48664
# 99410                       21.38822
# 99553                       21.38822
# 99698                       21.30534
#
# [760 rows x 21 columns]

# %%
gasolina_sp_18 = df.query('PRODUTO=="GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_sp_18.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92610   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92755   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92901   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92319                          1641              R$/l                3.988
# 92465                          1648              R$/l                4.002
# 92610                          1648              R$/l                4.006
# 92755                          1644              R$/l                4.019
# 92901                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 92319                  0.156                 3.499  ...                 0.411
# 92465                  0.155                 3.549  ...                 0.412
# 92610                  0.160                 3.499  ...                 0.410
# 92755                  0.156                 3.579  ...                 0.423
# 92901                  0.157                 3.579  ...                 0.416
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 92319                     0.039                     3.577
# 92465                     0.039                     3.590
# 92610                     0.040                     3.596
# 92755                     0.039                     3.596
# 92901                     0.039                     3.588
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92319                       0.104                      2.990
# 92465                       0.102                      2.990
# 92610                       0.102                      2.990
# 92755                       0.107                      2.924
# 92901                       0.102                      2.990
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 92319                     3.9510                          0.029    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92610                     3.9014                          0.028    1  2018
# 92755                     3.9537                          0.030    1  2018
# 92901                     3.9537                          0.028    2  2018
#
#        PREÇO MÉDIO REVENDA (dólares)
# 92319                       20.65784
# 92465                       20.73036
# 92610                       20.75108
# 92755                       20.81842
# 92901                       20.74072
#
# [5 rows x 21 columns]

# %%
gasolina_sp_18.shape
# Out:
# (52, 21)

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
gasolina_sp_18.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# 50%                 0.173000              3.679000              4.999000
# 75%                 0.189000              3.784000              5.099000
# max                 0.216000              3.969000              5.299000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count             52.000000                 52.000000
# mean               0.442481                  0.041750
# std                0.063271                  0.003965
# min                0.366000                  0.034000
# 25%                0.404500                  0.039000
# 50%                0.421500                  0.040000
# 75%                0.470250                  0.044000
# max                0.640000                  0.051000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count                 52.000000                   52.000000
# mean                   3.760288                    0.109654
# std                    0.163664                    0.010712
# min                    3.563000                    0.087000
# 25%                    3.620250                    0.102000
# 50%                    3.756500                    0.108000
# 75%                    3.862250                    0.116250
# max                    4.085000                    0.144000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count                   52.00000                  52.000000
# mean                     3.31295                   4.139454
# std                      0.26684                   0.195897
# min                      2.92400                   3.887500
# 25%                      2.99000                   3.965775
# 50%                      3.35000                   4.095500
# 75%                      3.53250                   4.259000
# max                      3.76000                   4.551000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO        MÊS     ANO  \
# count                      52.000000  52.000000    52.0
# mean                        0.029096   6.615385  2018.0
# std                         0.002460   3.470627     0.0
# min                         0.023000   1.000000  2018.0
# 25%                         0.028000   4.000000  2018.0
# 50%                         0.029000   7.000000  2018.0
# 75%                         0.030000   9.250000  2018.0
# max                         0.037000  12.000000  2018.0
#
#        PREÇO MÉDIO REVENDA (dólares)
# count                      52.000000
# mean                       21.770345
# std                         0.935881
# min                        20.564600
# 25%                        20.761440
# 50%                        21.766360
# 75%                        22.461775
# max                        23.372160

# %%
gasolina_sp_18['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
gasolinaetanol_sp_18 = df.query('PRODUTO=="GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolinaetanol_sp_18.head()
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 11980   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 11981   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 11982   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 11983   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 11984   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#               PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 11980  GASOLINA COMUM                           128              R$/l
# 11981  GASOLINA COMUM                           395              R$/l
# 11982  GASOLINA COMUM                           194              R$/l
# 11983  GASOLINA COMUM                           166              R$/l
# 11984  GASOLINA COMUM                           106              R$/l
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 11980                2.029                  0.007                  1.99  ...
# 11981                2.025                  0.062                  1.85  ...
# 11982                2.358                  0.066                  2.00  ...
# 11983                2.120                  0.075                  1.97  ...
# 11984                2.090                  0.034                  2.00  ...
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 11980                 0.318                     0.003
# 11981                 0.296                     0.031
# 11982                 0.472                     0.028
# 11983                 0.325                     0.035
# 11984                 0.350                     0.016
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 11980                     1.711                       0.020
# 11981                     1.729                       0.036
# 11982                     1.886                       0.068
# 11983                     1.795                       0.033
# 11984                     1.740                       0.042
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 11980                    1.65100                     1.7427
# 11981                    1.66430                     1.9150
# 11982                    1.75000                     2.0713
# 11983                    1.70701                     1.9703
# 11984                    1.67890                     1.9180
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  PREÇO MÉDIO REVENDA (dólares)
# 11980                          0.012    5  2004                       10.51022
# 11981                          0.021    5  2004                       10.48950
# 11982                          0.036    5  2004                       12.21444
# 11983                          0.018    5  2004                       10.98160
# 11984                          0.024    5  2004                       10.82620
#
# [5 rows x 21 columns]

# %%
lista_de_estados = ["GASOLINA COMUM", "ETANOL HIDRATADO"]
df.query('PRODUTO in @lista_de_estados and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...            ...         ...      ...        ...               ...
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92238                          1664              R$/l                2.833
# 92319                          1641              R$/l                3.988
# 92384                          1661              R$/l                2.868
# 92465                          1648              R$/l                4.002
# 92529                          1662              R$/l                2.874
# ...                             ...               ...                  ...
# 99410                          1637              R$/l                4.129
# 99472                          1662              R$/l                2.644
# 99553                          1641              R$/l                4.129
# 99617                          1661              R$/l                2.643
# 99698                          1643              R$/l                4.113
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 92238                  0.139                 2.449  ...                 0.338
# 92319                  0.156                 3.499  ...                 0.411
# 92384                  0.134                 2.399  ...                 0.331
# 92465                  0.155                 3.549  ...                 0.412
# 92529                  0.135                 2.399  ...                 0.324
# ...                      ...                   ...  ...                   ...
# 99410                  0.201                 3.699  ...                 0.490
# 99472                  0.163                 2.149  ...                 0.305
# 99553                  0.201                 3.699  ...                 0.484
# 99617                  0.161                 2.259  ...                 0.303
# 99698                  0.201                 3.599  ...                 0.503
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 92238                     0.049                     2.495
# 92319                     0.039                     3.577
# 92384                     0.047                     2.537
# 92465                     0.039                     3.590
# 92529                     0.047                     2.550
# ...                         ...                       ...
# 99410                     0.049                     3.639
# 99472                     0.062                     2.339
# 99553                     0.049                     3.645
# 99617                     0.061                     2.340
# 99698                     0.049                     3.610
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92238                       0.092                     2.1842
# 92319                       0.104                     2.9900
# 92384                       0.087                     2.2600
# 92465                       0.102                     2.9900
# 92529                       0.095                     1.6900
# ...                           ...                        ...
# 99410                       0.110                     3.3500
# 99472                       0.094                     2.0067
# 99553                       0.107                     3.3500
# 99617                       0.097                     1.9072
# 99698                       0.100                     3.3500
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 92238                     2.8833                          0.037    1  2018
# 92319                     3.9510                          0.029    1  2018
# 92384                     2.8471                          0.034    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92529                     2.9722                          0.037    1  2018
# ...                          ...                            ...  ...   ...
# 99410                     3.9892                          0.030   12  2018
# 99472                     2.7443                          0.040   12  2018
# 99553                     3.9892                          0.029   12  2018
# 99617                     2.7957                          0.041   12  2018
# 99698                     3.9585                          0.028   12  2018
#
#        PREÇO MÉDIO REVENDA (dólares)
# 92238                       14.67494
# 92319                       20.65784
# 92384                       14.85624
# 92465                       20.73036
# 92529                       14.88732
# ...                              ...
# 99410                       21.38822
# 99472                       13.69592
# 99553                       21.38822
# 99617                       13.69074
# 99698                       21.30534
#
# [104 rows x 21 columns]

# %%
gasolina_etanol_sp_18 = df.query('PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"] and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_etanol_sp_18
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...            ...         ...      ...        ...               ...
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92238                          1664              R$/l                2.833
# 92319                          1641              R$/l                3.988
# 92384                          1661              R$/l                2.868
# 92465                          1648              R$/l                4.002
# 92529                          1662              R$/l                2.874
# ...                             ...               ...                  ...
# 99410                          1637              R$/l                4.129
# 99472                          1662              R$/l                2.644
# 99553                          1641              R$/l                4.129
# 99617                          1661              R$/l                2.643
# 99698                          1643              R$/l                4.113
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 92238                  0.139                 2.449  ...                 0.338
# 92319                  0.156                 3.499  ...                 0.411
# 92384                  0.134                 2.399  ...                 0.331
# 92465                  0.155                 3.549  ...                 0.412
# 92529                  0.135                 2.399  ...                 0.324
# ...                      ...                   ...  ...                   ...
# 99410                  0.201                 3.699  ...                 0.490
# 99472                  0.163                 2.149  ...                 0.305
# 99553                  0.201                 3.699  ...                 0.484
# 99617                  0.161                 2.259  ...                 0.303
# 99698                  0.201                 3.599  ...                 0.503
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 92238                     0.049                     2.495
# 92319                     0.039                     3.577
# 92384                     0.047                     2.537
# 92465                     0.039                     3.590
# 92529                     0.047                     2.550
# ...                         ...                       ...
# 99410                     0.049                     3.639
# 99472                     0.062                     2.339
# 99553                     0.049                     3.645
# 99617                     0.061                     2.340
# 99698                     0.049                     3.610
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92238                       0.092                     2.1842
# 92319                       0.104                     2.9900
# 92384                       0.087                     2.2600
# 92465                       0.102                     2.9900
# 92529                       0.095                     1.6900
# ...                           ...                        ...
# 99410                       0.110                     3.3500
# 99472                       0.094                     2.0067
# 99553                       0.107                     3.3500
# 99617                       0.097                     1.9072
# 99698                       0.100                     3.3500
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 92238                     2.8833                          0.037    1  2018
# 92319                     3.9510                          0.029    1  2018
# 92384                     2.8471                          0.034    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92529                     2.9722                          0.037    1  2018
# ...                          ...                            ...  ...   ...
# 99410                     3.9892                          0.030   12  2018
# 99472                     2.7443                          0.040   12  2018
# 99553                     3.9892                          0.029   12  2018
# 99617                     2.7957                          0.041   12  2018
# 99698                     3.9585                          0.028   12  2018
#
#        PREÇO MÉDIO REVENDA (dólares)
# 92238                       14.67494
# 92319                       20.65784
# 92384                       14.85624
# 92465                       20.73036
# 92529                       14.88732
# ...                              ...
# 99410                       21.38822
# 99472                       13.69592
# 99553                       21.38822
# 99617                       13.69074
# 99698                       21.30534
#
# [104 rows x 21 columns]

# %%
#considerando os preços do etanol e da gasolina juntos, temos essas estatitiscas descritivas
gasolina_etanol_sp_18['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count           104.000000
# mean              3.457337
# std               0.766239
# min               2.393000
# 25%               2.726000
# 50%               3.431000
# 75%               4.199000
# max               4.512000

# %%
gasolina_etanol_sp_18.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
